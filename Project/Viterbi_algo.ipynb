# %%
# Importing the required libraries 
import nltk
import numpy as np
import itertools

# %%
# Downloading and importing the brown corpus
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
#Getting the tagged sentences
sent_tag = brown.tagged_sents()
mod_sent_tag=[]
for s in sent_tag:
  s.insert(0,('##','##'))
  s.append(('&&','&&'))
  mod_sent_tag.append(s)

# %%
#Splitting the data for train and test
split_num = int(len(mod_sent_tag)*0.9)
train_data = mod_sent_tag[0:split_num]
test_data = mod_sent_tag[split_num:]

# %%
#Creating a dictionary whose keys are tags and values contain words which were assigned the correspoding tag
# ex:- 'TAG':{word1: count(word1,'TAG')}
train_word_tag = {}
for s in train_data:
  for (w,t) in s:
    w=w.lower()
    try:
      try:
        train_word_tag[t][w]+=1
      except:
        train_word_tag[t][w]=1
    except:
      train_word_tag[t]={w:1}
train_word_tag
# Out:
# {'##': {'##': 51606},
#  'AT': {'the': 64805,
#   'an': 3456,
#   'no': 1649,
#   'a': 20956,
#   'every': 446,
#   "th'": 1},
#  'NP-TL': {'fulton': 10,
#   'atlanta': 4,
#   'grady': 4,
#   'georgia': 14,
#   'jackson': 2,
#   'miller': 2,
#   'colquitt': 1,
#   'texas': 17,
#   'dallas': 13,
#   'beaumont': 1,
#   'lamar': 2,
#   'texan': 1,
#   'wise': 1,
#   'paris': 3,
#   'oklahoma': 3,
#   'rhode': 99,
#   'massachusetts': 14,
#   'u.s.': 56,
#   'denton': 1,
#   'york': 285,
#   'st.': 11,
#   'louis': 13,
#   'cook': 2,
#   'republican': 9,
#   'atlantic': 6,
#   'viet': 10,
#   'nam': 9,
#   'lao': 3,
#   'boston': 11,
#   'america': 73,
#   'asia': 18,
#   'providence': 38,
#   'narragansett': 4,
#   'sheraton-biltmore': 3,
#   'johnston': 4,
#   'westfield': 2,
#   'jersey': 19,
#   'mack': 1,
#   'kennedy': 10,
#   'essex': 5,
#   'orange': 5,
#   'michigan': 5,
#   'morris': 3,
#   'brooklyn': 16,
#   'feis': 1,
#   'hunter': 3,
#   'u.': 36,
#   's.': 37,
#   'times-picayune': 1,
#   'orleans': 39,
#   'miles': 1,
#   'pennsylvania': 14,
#   'columbia': 16,
#   'lafayette': 6,
#   'samoa': 1,
#   'frankford': 1,
#   'hughes': 2,
#   'philadelphia': 13,
#   's.p.c.a.': 1,
#   'montgomery': 5,
#   'eastwick': 4,
#   'dicks': 1,
#   'grovers': 1,
#   'baptist': 6,
#   'portland': 3,
#   'multnomah': 5,
#   'germany': 18,
#   'kiwanis': 1,
#   'willamette': 3,
#   'beaverton': 1,
#   'god': 29,
#   'coliseum': 1,
#   'kansas': 11,
#   'miami': 11,
#   'florida': 3,
#   'york-pennsylvania': 1,
#   'clipper': 1,
#   'scrapiron': 1,
#   'patty': 1,
#   'columbus': 6,
#   'k.': 1,
#   'c.': 1,
#   'wellsley': 1,
#   'a.a.u.': 1,
#   'franklin': 4,
#   'yankee': 2,
#   'chicago': 28,
#   'washington': 28,
#   'stamford': 1,
#   'louisiana': 3,
#   'minnesota': 4,
#   'pacific': 2,
#   'ogden': 1,
#   'ebbetts': 1,
#   'cincinnati': 1,
#   'pittsburgh': 5,
#   'waldorf-astoria': 2,
#   'ben': 3,
#   'epstein': 1,
#   'babe': 1,
#   'ruth': 2,
#   'william': 1,
#   'j.': 3,
#   'slocum': 1,
#   'sid': 1,
#   'mercer': 3,
#   'flushing': 1,
#   'georgetown': 2,
#   'pierre': 1,
#   'canada': 3,
#   'hogan': 1,
#   'hickok': 1,
#   'warwick': 10,
#   'busch': 2,
#   'vern': 1,
#   'tipoff': 1,
#   'billiken': 1,
#   'missouri': 7,
#   'ligget': 1,
#   'harris': 3,
#   'c': 8,
#   'case': 1,
#   'vero': 2,
#   'arab': 1,
#   'passavant': 1,
#   'illinois': 13,
#   'playboy-show-biz': 1,
#   'drury': 3,
#   'jude': 3,
#   'england': 59,
#   'knight': 1,
#   'brandenburg': 1,
#   'african': 4,
#   'colorado': 4,
#   'brown': 38,
#   'denver': 2,
#   'teter': 1,
#   'larimer': 1,
#   'boxwood': 1,
#   'munger': 1,
#   'perkins': 1,
#   'sequoia': 2,
#   'presbyterian': 8,
#   'rhodes': 5,
#   'africa': 13,
#   'mayfair': 2,
#   'arlington': 2,
#   'slaughter': 1,
#   'philmont': 3,
#   'gimbel': 1,
#   'chester': 4,
#   'delaware': 11,
#   'wissahickon': 1,
#   'kimbolton': 1,
#   'fairless': 1,
#   'drexel': 5,
#   'delray': 1,
#   'newtown': 1,
#   'wellesley': 1,
#   'b.': 10,
#   'o.': 10,
#   'charles': 9,
#   'aiken': 1,
#   'anne': 4,
#   'arundel': 2,
#   'annapolis': 1,
#   'severna': 1,
#   'jones': 2,
#   'baltimore': 8,
#   'pratt': 5,
#   'maryland': 5,
#   'edgewater': 2,
#   'dodge': 2,
#   'johns-manville': 1,
#   'bow': 1,
#   'bailey': 2,
#   'westinghouse': 1,
#   'wabash': 1,
#   'dunbar': 2,
#   'stewart': 1,
#   'jenks': 1,
#   'sterling': 3,
#   'viceroy': 1,
#   'olivet': 1,
#   'lyle': 1,
#   'elliott': 1,
#   'serra': 1,
#   'david': 5,
#   'detroit': 4,
#   'pall': 1,
#   'tareytown': 1,
#   'warren': 4,
#   'fuhrmann': 1,
#   'dequindre': 1,
#   'mcclellan': 1,
#   'vernor': 1,
#   'delhi': 3,
#   'havana': 1,
#   'emory': 10,
#   'methodist': 2,
#   'waddell': 1,
#   'ponce': 1,
#   'leon': 1,
#   'venable': 1,
#   'marietta': 2,
#   'oakland': 1,
#   'nakoma': 1,
#   'blanche': 1,
#   'cain': 1,
#   'piedmont': 1,
#   'hood': 1,
#   'rotary': 1,
#   'oregon': 4,
#   'woodyard': 1,
#   'burnside': 1,
#   'mcneil': 1,
#   'phoenix': 1,
#   'ne': 2,
#   'schuyler': 1,
#   'bess': 2,
#   'kaiser': 1,
#   'macwhyte': 1,
#   'ward': 1,
#   'dalles': 1,
#   'lloyd': 1,
#   'kader': 1,
#   'voiture': 1,
#   'nevah': 1,
#   'sholom': 1,
#   'holman': 1,
#   'ohio': 11,
#   'wilson': 1,
#   'georgia-pacific': 2,
#   'bond': 1,
#   'nevada': 1,
#   'john': 42,
#   'haase': 1,
#   'cedar': 1,
#   'hartford': 2,
#   'desoto': 1,
#   'greenville': 2,
#   'eddy': 1,
#   'beverly': 9,
#   'fatima': 1,
#   'woonasquatucket': 1,
#   'stevens': 1,
#   'smith': 5,
#   'atwells': 1,
#   'fletcher': 1,
#   'jane': 1,
#   'uncas': 1,
#   'aurora': 1,
#   'macon': 1,
#   'prentice-hall': 1,
#   'audubon': 5,
#   'reyes': 1,
#   'marin': 2,
#   'greenwood': 1,
#   'olney': 1,
#   'easter': 1,
#   'madison': 8,
#   'kedzie': 1,
#   'best': 1,
#   'dearborn': 2,
#   'lawrence': 4,
#   'sherman': 4,
#   'morton': 7,
#   'guerin': 1,
#   'turner': 2,
#   'murray': 1,
#   'hardwicke-etter': 1,
#   'lummus': 1,
#   'moss': 1,
#   'gordin': 2,
#   'hinckley': 1,
#   'stacy': 1,
#   'sheraton-dallas': 2,
#   'isodine': 1,
#   'gaither': 1,
#   'anderson': 1,
#   'berlin': 31,
#   'bell': 2,
#   'howell': 1,
#   'taylor': 5,
#   'california': 21,
#   'kawecki': 1,
#   'chesapeake': 3,
#   'harvester': 3,
#   'ford': 4,
#   'neiman-marcus': 1,
#   'byer-rolnick': 1,
#   'mexico': 13,
#   'down': 1,
#   'orkney': 1,
#   'london': 8,
#   'grenoble': 1,
#   'birmingham': 2,
#   'james': 9,
#   'forsythe': 1,
#   'campobello': 1,
#   'mcelvaney': 1,
#   'hockaday': 1,
#   'morocco': 1,
#   'cadillac': 1,
#   'pontiac': 1,
#   'chisholm': 2,
#   'hilton': 2,
#   'los': 7,
#   'angeles': 7,
#   'wilshire': 1,
#   'budapest': 3,
#   'arden': 3,
#   'laguna': 2,
#   'oceania': 1,
#   'roger': 1,
#   'bahia': 1,
#   'judson': 1,
#   'galt': 1,
#   'heilman': 1,
#   'sunman': 1,
#   'mackey': 1,
#   'milenoff': 1,
#   'ximenez-vargas': 1,
#   'hollywood': 4,
#   'thomas': 5,
#   'aquinas': 1,
#   'stranahan': 1,
#   'pompano': 1,
#   'christ': 7,
#   'dade': 2,
#   'trinity': 1,
#   'leningrad': 2,
#   'kirov': 4,
#   'petipa-tschaikowsky': 1,
#   'russia': 5,
#   'mills': 2,
#   'roosevelt': 5,
#   'howard': 1,
#   'tv': 2,
#   'transylvania': 2,
#   'brevard': 1,
#   'england-born': 1,
#   'rainier': 1,
#   'carolina': 17,
#   'vernon': 3,
#   'washington-alexandria': 1,
#   'laos': 1,
#   'vietnam': 3,
#   'notre': 3,
#   'dame': 3,
#   'wagner': 2,
#   'taft-hartley': 2,
#   'landrum-griffin': 2,
#   'danbury': 1,
#   'loewe': 1,
#   'clayton': 3,
#   'coronado': 1,
#   'eisenhower': 4,
#   'china': 9,
#   'augusta': 2,
#   'cancer': 1,
#   'zealand': 3,
#   'rhine-westphalia': 1,
#   'wayne': 2,
#   'nobel': 5,
#   'europe': 24,
#   'morgan': 1,
#   'congo': 5,
#   'britain': 14,
#   'kasai': 1,
#   'u.n.': 3,
#   'mongolia': 1,
#   'boeing': 1,
#   'blyth': 1,
#   'virginia': 12,
#   'marshall': 5,
#   'lancashire': 1,
#   'wales': 2,
#   'nassau': 4,
#   'nanook': 1,
#   'coosa': 2,
#   'milledgeville': 1,
#   'dominican': 6,
#   'george': 5,
#   'german': 5,
#   'pottawatomie': 1,
#   "k's": 1,
#   'rhodesia': 1,
#   'goodbody': 1,
#   'graves': 2,
#   'congress': 21,
#   'carbondale': 1,
#   'tammany': 3,
#   'chatham': 1,
#   'cunard': 1,
#   'mekong': 2,
#   'castro': 1,
#   'dekalb': 3,
#   'matthew': 2,
#   'luke': 1,
#   'a': 14,
#   'b': 8,
#   'field': 2,
#   'moscow': 3,
#   'warsaw': 1,
#   'ziegfeld': 2,
#   'amsterdam': 1,
#   'korea': 2,
#   'bible': 13,
#   'english': 9,
#   'yale': 6,
#   'scotland': 5,
#   'dover': 1,
#   'birch': 1,
#   'greenwich': 22,
#   'hampshire': 10,
#   'kent': 11,
#   'gabrielle': 1,
#   'beth': 1,
#   'el': 1,
#   'mathewson': 1,
#   'pleasant': 1,
#   'depaul': 2,
#   'newark': 2,
#   'may': 5,
#   'cretaceous': 1,
#   'mayflower': 3,
#   'jefferson': 2,
#   'woodward': 1,
#   'trumbull': 1,
#   'schuylkill': 4,
#   'guiana': 2,
#   'cornell': 2,
#   'manchester': 26,
#   'un': 1,
#   'vatican': 1,
#   'canterbury': 4,
#   'eisenhhower': 1,
#   'molly': 1,
#   'yum-yum': 1,
#   'frank': 1,
#   'grecian': 1,
#   'hong': 1,
#   'kong': 1,
#   'casbah': 1,
#   'molotov': 1,
#   'connally': 1,
#   'devens': 1,
#   'toronto': 1,
#   'katanga': 2,
#   'pitney-bowes': 1,
#   'indonesia': 2,
#   'celebes': 1,
#   'eleanor': 1,
#   'godkin': 2,
#   'harvard': 13,
#   'tizard': 1,
#   'brahms': 1,
#   'bayreuth': 2,
#   'tannhaeuser': 2,
#   'dutch': 1,
#   'bolshoi': 1,
#   'leningrad-kirov': 1,
#   'mccormick': 1,
#   'dietrich': 1,
#   'davis': 1,
#   'gore': 3,
#   'du': 1,
#   'pont': 1,
#   'timex': 1,
#   'dixieland': 2,
#   'covent': 2,
#   'lewisohn': 4,
#   'kabalevsky': 1,
#   'burma': 1,
#   'britten': 1,
#   'century-fox': 1,
#   'newport': 4,
#   'dillon': 3,
#   'charley': 3,
#   'amy': 1,
#   'gibson': 2,
#   'broadway': 2,
#   'pulitzer': 3,
#   'zeme': 1,
#   'yorker': 5,
#   'henry': 3,
#   'virginian': 1,
#   'yalta': 4,
#   'morgenthau': 2,
#   'baltic': 2,
#   'potsdam': 1,
#   'beethoven': 3,
#   'sylvie': 1,
#   'spycket': 1,
#   'carnegie': 5,
#   'guignol': 1,
#   'robert': 2,
#   'hannah': 1,
#   'savannah': 1,
#   'bill': 1,
#   'ike': 1,
#   'isaacs': 1,
#   'helen': 2,
#   'tamiris-daniel': 1,
#   'nagrin': 1,
#   'lincoln': 8,
#   'westchester': 3,
#   'leonore': 1,
#   'rodgers': 1,
#   'hart': 1,
#   'garrick': 2,
#   'roxy': 1,
#   'connecticut': 3,
#   'wao': 1,
#   'gorky': 1,
#   'phedre': 3,
#   'tartuffe': 1,
#   'scapin': 1,
#   'ory': 1,
#   'bourbon': 1,
#   'panama': 2,
#   'tootsie': 1,
#   'beale': 1,
#   'taras': 2,
#   'bulba': 2,
#   'carmen': 1,
#   'negro': 2,
#   'sloan': 1,
#   'wilmington': 1,
#   'gloucester': 2,
#   'bleeker': 1,
#   'carmine': 1,
#   'elizabeth': 2,
#   'cambridge': 3,
#   'shakespeare': 2,
#   'wollman': 2,
#   'arragon': 1,
#   'riviera': 1,
#   'moiseyev': 1,
#   'kalmuk': 1,
#   'azerbaijan': 1,
#   'shenandoah': 1,
#   'vilas': 1,
#   'mackinac': 1,
#   'shawnee': 1,
#   'dakota': 6,
#   'lewis': 1,
#   'clark': 2,
#   'longwood': 1,
#   'kennett': 1,
#   'iberia': 1,
#   'niagara': 2,
#   'falmouth': 1,
#   'staten': 5,
#   'dana': 1,
#   'mead': 1,
#   'isabel': 1,
#   'mississippi': 6,
#   'mckellar': 1,
#   'arkabutla': 1,
#   'pontchartrain': 2,
#   'tennessee': 2,
#   'vendome': 1,
#   'alamein': 1,
#   'albert': 2,
#   'johnny': 2,
#   'quaker': 1,
#   'netherlands': 2,
#   'rockefeller': 5,
#   'christendom': 2,
#   'guy': 3,
#   'fawkes': 3,
#   'rome': 4,
#   'liverpool': 1,
#   'han': 1,
#   'sky-god': 1,
#   "preparation-inquirers'": 1,
#   'israel': 3,
#   'pakistan': 1,
#   'wesleyan': 1,
#   'nantucket': 1,
#   'andover': 1,
#   'congregationalism': 1,
#   'jesus': 1,
#   'nova': 1,
#   'lane': 1,
#   'uncle': 1,
#   'tien': 1,
#   'tai': 1,
#   'buddha': 1,
#   'peter': 6,
#   'montreal': 1,
#   'weider': 1,
#   'vienna': 3,
#   'hephzibah': 1,
#   'menuhin-amadeus': 1,
#   'demus-schubert': 1,
#   'parsifal': 1,
#   'scheherazade': 1,
#   'giselle': 2,
#   'westminster': 2,
#   'thoroughbred': 1,
#   'setter': 2,
#   'leonard': 1,
#   'brumby': 1,
#   'sr.': 1,
#   'airedale': 1,
#   'kerry': 1,
#   'kcs': 1,
#   'kc': 1,
#   'texoma': 2,
#   'lexington': 2,
#   'white': 1,
#   'valentine': 1,
#   'armbro': 1,
#   'scotch': 1,
#   'lullwater': 1,
#   'braden': 1,
#   'magnum': 3,
#   'wesson': 1,
#   'coltsman': 1,
#   'kodiak': 1,
#   'savage': 1,
#   '514c': 1,
#   '940y': 1,
#   'supermatic': 1,
#   'flite-king': 1,
#   'belmont': 1,
#   'nob': 1,
#   'hudson': 12,
#   'sturbridge': 1,
#   'acadia': 1,
#   'champlain': 3,
#   'ethan': 4,
#   'allen': 5,
#   'adirondack': 1,
#   'winooski': 2,
#   'luray': 1,
#   'wisconsin': 5,
#   'theodore': 2,
#   'rushmore': 1,
#   'itasca': 1,
#   'abilene': 1,
#   'mackinack': 1,
#   'hiawatha': 1,
#   'arkansas': 5,
#   'yosemite': 1,
#   'zion': 1,
#   'bryce': 1,
#   'marmara': 3,
#   'taksim': 1,
#   'dolmabahce': 1,
#   'galata': 1,
#   'sophia': 7,
#   'eminonu': 1,
#   'artemis': 1,
#   'theodosius': 1,
#   'apollo': 3,
#   'ahmet': 2,
#   'constantine': 2,
#   'bayezit': 1,
#   'topkapi': 1,
#   'irene': 1,
#   'coney': 3,
#   'merc': 1,
#   'weldwood': 1,
#   'porter': 1,
#   'aj': 11,
#   'merrimac': 1,
#   'salisbury': 1,
#   'merrimack': 3,
#   'malden': 1,
#   'new-england': 1,
#   'new-york': 1,
#   'boxford': 1,
#   'fayette': 2,
#   'tygartis': 1,
#   'fairmont': 1,
#   'parkersburg': 1,
#   'staunton': 1,
#   'philippi': 1,
#   'barbour': 1,
#   'soviet': 14,
#   'ranger': 2,
#   'joseph': 4,
#   'pennell': 1,
#   'blair': 1,
#   'copenhagen': 2,
#   'bavaria': 1,
#   'france': 3,
#   'mo.': 1,
#   'abraham': 1,
#   'strauss': 1,
#   'hatteras': 1,
#   'dutchess': 2,
#   'oakwood': 5,
#   'timen': 1,
#   'waters': 1,
#   'chrysler': 1,
#   'kahler-craft': 1,
#   'slo-flo': 1,
#   'h': 5,
#   'adaptaplex': 1,
#   'merritt': 1,
#   'stanley': 1,
#   'spain': 2,
#   'auto-europe': 1,
#   'nationalcar': 1,
#   'fiat': 5,
#   'chevrolet': 1,
#   'austin': 1,
#   'citroen': 1,
#   'buffalo': 2,
#   'alexandria': 1,
#   'harvey': 8,
#   '2/c': 1,
#   '1/c': 2,
#   'sorrentine': 1,
#   'junkers': 1,
#   'assyrian': 1,
#   'northfield': 1,
#   'vermont': 5,
#   'barre': 1,
#   'englander': 5,
#   'concord': 1,
#   'curtiss': 1,
#   'winnipesaukee': 1,
#   'burlington': 1,
#   'd.a.': 1,
#   'x': 1,
#   'semiramis': 1,
#   'vrilium': 1,
#   'eichmann': 1,
#   'wansee': 1,
#   'reich': 1,
#   'lambeth': 3,
#   'galway': 1,
#   'muscovy': 3,
#   'india': 23,
#   'baffin': 1,
#   'ungava': 1,
#   'selkirk': 1,
#   'indiana': 1,
#   'douglas': 4,
#   'pembina': 1,
#   'daer': 5,
#   'indian': 1,
#   'anthony': 1,
#   'garry': 7,
#   'snelling': 4,
#   'alabama': 5,
#   'hawthorne': 1,
#   'bridewell': 1,
#   'webster': 1,
#   'la': 5,
#   'salle': 2,
#   'osaka': 1,
#   'scripps': 1,
#   'hilo': 1,
#   'pololu': 1,
#   'noctiluca': 1,
#   'sagami': 1,
#   'kamchatka': 1,
#   'honolulu': 1,
#   'limerick': 1,
#   'shannon': 1,
#   'owen': 1,
#   'cav': 1,
#   'naktong': 2,
#   'g': 2,
#   'garryowen': 1,
#   'indochina': 1,
#   'bolovens': 1,
#   'midwood': 1,
#   'witt': 1,
#   'fife': 1,
#   'lauderdale': 1,
#   'norton': 1,
#   'hopedale': 1,
#   'bartholf': 1,
#   'stonehenge': 1,
#   'belasco': 2,
#   'dolley': 1,
#   'holyoke': 1,
#   'moosilauke': 1,
#   'dartmouth': 4,
#   'mckinley': 1,
#   'thayer': 2,
#   'amos': 1,
#   'tuck': 1,
#   'bedford': 2,
#   'standard-times': 1,
#   'weybosset': 1,
#   'bethlehem': 1,
#   'spelman': 2,
#   'packard': 1,
#   'rover': 1,
#   'art': 1,
#   'shires': 1,
#   'fenway': 1,
#   'american': 4,
#   'nordyke': 1,
#   'marmon': 1,
#   'aventine': 1,
#   'malta': 1,
#   'via': 3,
#   'di': 3,
#   'santa': 3,
#   'prisca': 1,
#   'capitoline': 1,
#   'marcellus': 1,
#   'octavia': 1,
#   'san': 12,
#   'carlo': 1,
#   'ai': 1,
#   'catinari': 1,
#   "sant'": 2,
#   'andrea': 1,
#   'della': 1,
#   'valle': 1,
#   'pompey': 1,
#   'maxentius': 1,
#   'agnese': 2,
#   'agone': 2,
#   'isis': 1,
#   'neptune': 1,
#   'mary': 4,
#   'menlo': 1,
#   'protestantism': 1,
#   'toulouse': 1,
#   'louisiane': 1,
#   'mike': 2,
#   'tokyo': 2,
#   'japan': 1,
#   'kyoto': 2,
#   'hoover': 1,
#   'sherwood': 1,
#   'offutt': 1,
#   'dutchman': 1,
#   'cologne': 3,
#   'frankfurt': 4,
#   'manon': 1,
#   'lescaut': 1,
#   'palestine': 1,
#   'francisco': 5,
#   'falstaff': 1,
#   'boheme': 1,
#   'frick': 1,
#   'albany': 3,
#   'buena': 1,
#   'vista': 1,
#   'yankeefication': 1,
#   'gothicism': 1,
#   'tara': 1,
#   'yoknapatawpha': 2,
#   'moses': 1,
#   'sumter': 2,
#   'godot': 4,
#   'tijuana': 1,
#   'venice': 5,
#   'eros': 1,
#   'vattern': 1,
#   'hans': 13,
#   'alienus': 1,
#   'baker': 1,
#   'alexander': 1,
#   'christianity': 1,
#   'gatsby': 1,
#   'porgy': 1,
#   'il': 1,
#   'pecorone': 1,
#   'palomar': 1,
#   'oedipus': 3,
#   'sheridan': 1,
#   'munich': 1,
#   'loire': 1,
#   'arbeitskommando': 1,
#   'dutton': 1,
#   'paul': 1,
#   'rosenberg': 1,
#   'oceana': 1,
#   'almagest': 4,
#   'nicholas': 2,
#   'cusa': 1,
#   'oresme': 1,
#   'dickens': 1,
#   'johns': 4,
#   'hopkins': 4,
#   'rodeph': 1,
#   'shalom': 1,
#   'lombard': 1,
#   'andromache': 1,
#   'tahoe': 1,
#   'appalachian': 1,
#   'volstead': 1,
#   'ursuline': 1,
#   'augustine': 1,
#   'princeton': 1,
#   'athearn': 1,
#   'gross': 2,
#   'bengal': 2,
#   'hooghli': 1,
#   'irrawaddy': 1,
#   'tory': 1,
#   'tatler': 1,
#   'englishman': 6,
#   'ireland': 1,
#   'stuart': 2,
#   'richard': 2,
#   'steele': 1,
#   'jack': 2,
#   'hanover': 2,
#   'bath': 1,
#   'cr--spe': 1,
#   'june': 1,
#   'woodberry': 1,
#   'susie': 1,
#   'american-negro': 3,
#   'bernard': 1,
#   'hearst': 2,
#   'smithsonian': 1,
#   'alto': 1,
#   'louisville': 1,
#   'courier-journal': 1,
#   'garibaldi': 1,
#   'messina': 1,
#   'manin': 1,
#   'bright': 2,
#   'grey': 1,
#   'regius': 2,
#   'savoy': 2,
#   'ramillies': 1,
#   'rhine': 2,
#   'strasbourg': 2,
#   'kehl': 1,
#   'france-germany': 1,
#   'christmas': 2,
#   'cumberland': 1,
#   'bug': 1,
#   'turk': 2,
#   'ekaterinoslav': 1,
#   'cossack': 1,
#   'poland': 1,
#   'pallavicini': 1,
#   'anhalt-bernburg': 1,
#   'pe': 1,
#   'pope': 1,
#   'july': 2,
#   'samuel': 1,
#   'gorton': 1,
#   'pawcatuck': 1,
#   'gaspee': 1,
#   'asheville': 1,
#   'riverside': 1,
#   'houghton': 1,
#   'graham': 2,
#   'borneo': 1,
#   'ion': 1,
#   'valois': 1,
#   'burgundy': 1,
#   'adolf': 1,
#   'habsburg': 1,
#   'edward': 3,
#   'jew': 1,
#   'meltzer': 4,
#   'kingston': 2,
#   'banks': 3,
#   'victoria': 1,
#   'guest': 1,
#   'crawford': 1,
#   'saxon': 14,
#   'grande-bretagne': 1,
#   'domesday': 1,
#   'anglia': 1,
#   'ctca': 1,
#   'armentieres': 1,
#   'romeo': 1,
#   'juliet': 1,
#   'lear': 3,
#   'feversham': 1,
#   'nouvelle-heloise': 1,
#   'werther': 1,
#   'athalie': 1,
#   'oresteia': 1,
#   'macbeth': 1,
#   'wilhelm': 1,
#   'meister': 1,
#   'faust': 1,
#   'troy': 2,
#   'faustus': 1,
#   'marston': 1,
#   'quiney': 1,
#   'watling': 1,
#   'canning': 1,
#   'wycombe': 1,
#   'gregory': 1,
#   'irving': 1,
#   'job': 1,
#   'glasgow': 1,
#   ...},
#  'NN-TL': {'county': 81,
#   'jury': 3,
#   'city': 124,
#   'committee': 85,
#   'court': 110,
#   'judge': 38,
#   'mayor-nominate': 1,
#   'department': 162,
#   'legislature': 27,
#   'state': 249,
#   'welfare': 6,
#   'bar': 8,
#   'association': 85,
#   'jail': 4,
#   'tax': 9,
#   'office': 40,
#   'hospital': 33,
#   'health': 16,
#   'mayor': 29,
#   'rd.': 3,
#   'ridge': 6,
#   'party': 21,
#   'chairman': 18,
#   'sen.': 30,
#   'highway': 7,
#   'lt.': 8,
#   'gov.': 19,
#   'senate': 57,
#   'authority': 10,
#   'constitution': 35,
#   'rep.': 13,
#   'house': 184,
#   'commerce': 40,
#   'board': 66,
#   'education': 36,
#   'ordinary': 2,
#   'policeman': 1,
#   'sheriff': 5,
#   'revenue': 14,
#   'taxation': 1,
#   'agency': 7,
#   'school': 71,
#   'navigation': 1,
#   'district': 56,
#   'gulf': 16,
#   'coast': 23,
#   'research': 25,
#   'league': 40,
#   'commission': 76,
#   'paradise': 7,
#   'fort': 41,
#   'mission': 11,
#   'sulphur': 1,
#   'college': 92,
#   'dr.': 181,
#   'doctor': 10,
#   'university': 122,
#   'master': 10,
#   'science': 19,
#   'bachelor': 2,
#   'island': 126,
#   'institute': 45,
#   'technology': 8,
#   'signal': 7,
#   'corps': 80,
#   'army': 73,
#   'supt.': 2,
#   'co.': 48,
#   'president': 255,
#   'cape': 16,
#   'cod': 5,
#   'executive': 4,
#   'port': 7,
#   'capitol': 21,
#   'hill': 32,
#   'leader': 5,
#   'speaker': 25,
#   'treaty': 7,
#   'organization': 18,
#   'council': 74,
#   'assembly': 28,
#   'secretary': 150,
#   'soviet': 98,
#   'union': 102,
#   'cooperation': 3,
#   'development': 23,
#   'communist': 66,
#   'cabinet': 5,
#   'vice-president': 3,
#   'senator': 34,
#   'prince': 29,
#   'delinquency': 2,
#   'crime': 2,
#   'attorney': 36,
#   'labor': 24,
#   'youth': 5,
#   'bureau': 25,
#   'investigation': 8,
#   'defense': 41,
#   'fire': 16,
#   'chief': 22,
#   'station': 11,
#   'race': 3,
#   'track': 1,
#   'governor': 29,
#   'atty.': 4,
#   'bay': 38,
#   'club': 66,
#   'hotel': 41,
#   'socialist': 3,
#   'screw': 1,
#   'group': 8,
#   'town': 11,
#   'solicitor': 3,
#   'park': 42,
#   'country': 12,
#   'federation': 12,
#   'truck': 1,
#   'administration': 58,
#   'woodland': 1,
#   'ave.': 13,
#   'supervisor': 2,
#   'freeholder': 1,
#   'conservation': 5,
#   'commissioner': 12,
#   'forest': 26,
#   'section': 47,
#   'cross': 9,
#   'inn': 4,
#   'bank': 29,
#   'controller': 8,
#   'representative': 6,
#   'campus': 2,
#   'act': 114,
#   'peace': 59,
#   'government': 141,
#   'premier': 24,
#   'secretariat': 5,
#   'minister': 15,
#   'princess': 5,
#   'company': 69,
#   'air': 38,
#   'field': 21,
#   'avenue': 38,
#   'war': 156,
#   'square': 28,
#   'gen.': 19,
#   'battle': 8,
#   'navy': 19,
#   'force': 27,
#   'guard': 13,
#   'virgin': 24,
#   'canal': 3,
#   'zone': 1,
#   'congressman': 14,
#   'steel': 6,
#   'erection': 1,
#   'transportation': 2,
#   'property': 2,
#   'director': 24,
#   'st.': 99,
#   'indemnity': 1,
#   'casualty': 1,
#   'finance': 4,
#   'home': 12,
#   'councilwoman': 1,
#   'redevelopment': 4,
#   'area': 5,
#   'corp.': 11,
#   'stage': 2,
#   'metal': 2,
#   'reconstruction': 3,
#   'battalion': 1,
#   'law': 19,
#   'world': 98,
#   'day': 42,
#   'emerald': 1,
#   'empire': 13,
#   'circuit': 4,
#   'no.': 53,
#   'temple': 15,
#   'oak': 7,
#   'lodge': 5,
#   'water': 6,
#   'testament': 22,
#   'diety': 1,
#   'lord': 59,
#   'breakthrough': 2,
#   'dist.': 3,
#   'major-league': 1,
#   'shortstop': 1,
#   'palm': 4,
#   'beach': 24,
#   'stadium': 19,
#   'flock': 3,
#   'grapefruit': 1,
#   'manager': 8,
#   'garden': 13,
#   'purse': 2,
#   'jockey': 1,
#   'self': 2,
#   'football': 6,
#   'white': 3,
#   'conference': 35,
#   'longhorn': 2,
#   'cotton': 6,
#   'bowl': 3,
#   'coach': 5,
#   'academy': 18,
#   'quarterback': 1,
#   'rookie': 1,
#   'lefty': 2,
#   'red': 1,
#   'outfielder': 1,
#   'diving': 1,
#   'champion': 3,
#   'railroad': 11,
#   'writer': 2,
#   'examiner': 8,
#   'traveler': 1,
#   'candlestick': 1,
#   'room': 15,
#   'series': 7,
#   'chapter': 27,
#   'baseball': 3,
#   'guy': 1,
#   'award': 7,
#   'meadow': 4,
#   'point': 19,
#   'golf': 6,
#   'cup': 1,
#   'amateur': 2,
#   'tee': 1,
#   'trophy': 6,
#   'open': 8,
#   'sportsman': 2,
#   'year': 9,
#   'athlete': 1,
#   'belt': 2,
#   'vinegar': 1,
#   'bend': 4,
#   'cardinal': 7,
#   'pirate': 2,
#   'man': 25,
#   'contribution': 1,
#   'basketball': 1,
#   'invitation': 2,
#   'tournament': 2,
#   'crystal': 5,
#   'u.': 1,
#   'class': 37,
#   'major': 13,
#   'polo': 3,
#   'lake': 40,
#   'cancer': 3,
#   'foundation': 19,
#   'opera': 18,
#   'place': 14,
#   'press': 17,
#   'lawn': 1,
#   'tennis': 3,
#   'fashion': 1,
#   'trade': 9,
#   'industry': 5,
#   'republic': 33,
#   'debutante': 1,
#   'cotillion': 1,
#   'casino': 1,
#   'consul': 2,
#   'actress': 1,
#   'towne': 1,
#   'art': 14,
#   'columnist': 1,
#   'skylark': 1,
#   'lane': 9,
#   'mag': 1,
#   'leukemia': 1,
#   'post': 23,
#   'box': 4,
#   'gift': 1,
#   'time': 20,
#   'lover': 3,
#   'flower': 4,
#   'drum': 1,
#   'song': 12,
#   'brain': 1,
#   'stock': 6,
#   'gate': 4,
#   'sentry': 1,
#   'loop': 5,
#   'tribune': 12,
#   'angel': 9,
#   'twist': 1,
#   'mercy': 1,
#   'palace': 23,
#   'brig.': 1,
#   'security': 17,
#   'life': 29,
#   'bldg.': 3,
#   'glass': 3,
#   'salvation': 3,
#   'center': 36,
#   'mom': 2,
#   'week': 14,
#   'skid': 1,
#   'row': 1,
#   'vacancy': 1,
#   'shamrock': 2,
#   'motel': 4,
#   'church': 120,
#   'theology': 1,
#   'gamma': 1,
#   'mortar': 1,
#   'fellowship': 8,
#   'chapel': 8,
#   'night': 9,
#   'thrift': 5,
#   'shop': 7,
#   'basin': 1,
#   'street': 89,
#   'walnut': 7,
#   'col.': 7,
#   'troop': 7,
#   'artist': 2,
#   'valley': 24,
#   'book': 14,
#   'cmdr.': 1,
#   'queen': 19,
#   'carnival': 7,
#   'briar': 1,
#   'pl.': 2,
#   'auditorium': 6,
#   'mount': 16,
#   'gold': 1,
#   'councilman': 5,
#   'spring': 12,
#   'grove': 4,
#   'capt.': 5,
#   'manor': 2,
#   'trooper': 1,
#   'route': 9,
#   'agriculture': 10,
#   'corporation': 19,
#   'harbor': 18,
#   'view': 2,
#   'cherry': 3,
#   'av.': 9,
#   'way': 14,
#   'prairie': 3,
#   'ledge': 2,
#   'prosecutor': 6,
#   'township': 4,
#   'mound': 2,
#   'mt.': 3,
#   'cemetery': 4,
#   'funeral': 3,
#   'mile': 5,
#   'road': 14,
#   'mother': 6,
#   'mall': 2,
#   'village': 22,
#   'line': 13,
#   'patrolman': 4,
#   'traffic': 2,
#   'correction': 1,
#   'ambassador': 13,
#   'legion': 5,
#   'wheel': 1,
#   'knoll': 1,
#   'cir.': 1,
#   'appeal': 5,
#   'cafeteria': 1,
#   'apartment': 2,
#   'slate': 5,
#   'hall': 37,
#   'expressway': 7,
#   'patrol': 3,
#   'rte.': 2,
#   'river': 83,
#   'administrator': 1,
#   'service': 66,
#   'grocery': 1,
#   'detective': 5,
#   'gateway': 1,
#   'shopping': 1,
#   'abbey': 6,
#   'local': 3,
#   'blvd.': 4,
#   'northwest': 8,
#   'fair': 3,
#   'harmony': 2,
#   'rite': 5,
#   'shrine': 2,
#   'order': 10,
#   'congregation': 1,
#   'son': 21,
#   'achievement': 8,
#   'sw': 1,
#   'ct.': 1,
#   'pumpkin': 1,
#   'mill': 1,
#   'drive': 10,
#   'elm': 1,
#   'brook': 2,
#   'incinerator': 1,
#   'circle': 2,
#   'lady': 30,
#   'maple': 1,
#   'fruit': 2,
#   'fund': 20,
#   'hose': 1,
#   'mfg.': 1,
#   'merit': 2,
#   'freedom': 6,
#   'rider': 2,
#   'graduate': 1,
#   'society': 40,
#   'convention': 5,
#   'wilderness': 1,
#   'sanctuary': 1,
#   'space': 9,
#   'division': 37,
#   'celebration': 1,
#   'march': 4,
#   'disarmament': 1,
#   'shore': 15,
#   'maintenance': 4,
#   'liquor': 1,
#   'sanitation': 3,
#   'supply': 4,
#   'loan': 3,
#   'gin': 6,
#   'cen-tennial': 2,
#   'lint': 1,
#   'cleaner': 1,
#   'unit': 5,
#   'system': 23,
#   'cliff': 1,
#   'sunset': 2,
#   'housing': 9,
#   'mortgage': 1,
#   'trust': 2,
#   'investment': 3,
#   'assn.': 2,
#   'reserve': 11,
#   'wall': 16,
#   'treasury': 38,
#   'exchange': 9,
#   'oil': 8,
#   'foil': 1,
#   'camera': 2,
#   'growth': 3,
#   'television-electronics': 1,
#   'round': 1,
#   'motor': 3,
#   'exposition': 2,
#   'ballroom': 1,
#   'hat': 1,
#   'palsy': 1,
#   'treatment': 2,
#   'repertory': 1,
#   'end': 7,
#   'arrow': 1,
#   'music': 14,
#   'theater': 13,
#   'harvest': 2,
#   'pride': 2,
#   'prejudice': 1,
#   'saga': 1,
#   'sunrise': 2,
#   'captain': 32,
#   'conversion': 1,
#   'symphony': 23,
#   'orchestra': 19,
#   'museum': 15,
#   'tuberculosis': 1,
#   'student': 14,
#   'dining': 1,
#   'king': 49,
#   'chicken': 3,
#   'heritage': 5,
#   'studio': 3,
#   'composite': 3,
#   'stagecoach': 2,
#   'trail': 2,
#   'mineral': 1,
#   'wells': 1,
#   'building': 12,
#   'register': 7,
#   'century': 23,
#   'bonanza': 1,
#   'lounge': 3,
#   'fireside': 1,
#   'steak': 2,
#   'ranch': 1,
#   'cabana': 1,
#   'rum': 1,
#   'ocean': 2,
#   'tune': 1,
#   'cafe': 5,
#   'chef': 1,
#   'restaurant': 4,
#   'sunshine': 1,
#   'playboy': 1,
#   'mouse': 1,
#   'trap': 1,
#   'escape': 2,
#   'ballet': 11,
#   'coral': 3,
#   'theatre': 9,
#   'library': 14,
#   'workshop': 5,
#   'plant': 2,
#   'crusade': 4,
#   'communism': 30,
#   'communisn': 1,
#   'map': 1,
#   'operation': 6,
#   'abolition': 2,
#   'family': 16,
#   'ter.': 1,
#   'dedication': 1,
#   'marriage': 2,
#   'altar': 1,
#   'coconut': 1,
#   'anniversary': 3,
#   'radio': 6,
#   'concert': 4,
#   'beauty': 2,
#   'lilac': 1,
#   'fairy': 1,
#   'chamber': 15,
#   'chronicle': 1,
#   'chestnut': 4,
#   'strip': 1,
#   'monthly': 3,
#   'channel': 6,
#   'person': 2,
#   'summer': 2,
#   'festival': 14,
#   'threshold': 1,
#   'action': 1,
#   'tranquility': 1,
#   'mansion': 1,
#   'star': 9,
#   'banner': 2,
#   'marine': 13,
#   'band': 9,
#   'conductor': 1,
#   'gallery': 13,
#   'cathedral': 2,
#   'confederacy': 6,
#   'renaissance': 9,
#   'nw.': 1,
#   'jurisdiction': 1,
#   'skyline': 4,
#   'camp': 6,
#   'control': 10,
#   'embassy': 8,
#   'business': 26,
#   'aircraft': 5,
#   'general': 89,
#   'electric': 4,
#   'folklore': 2,
#   'capitalism': 3,
#   'p.': 4,
#   'recovery': 2,
#   'wealth': 2,
#   'parliament': 12,
#   'justice': 19,
#   'report': 19,
#   'aeronautics': 2,
#   'mine': 1,
#   'coal': 4,
#   'dictator': 3,
#   'president-elect': 5,
#   'secretary-designate': 1,
#   'sea': 15,
#   'task': 1,
#   'inauguration': 5,
#   'southerner': 8,
#   'rule': 5,
#   'dealer': 1,
#   'election': 3,
#   'course': 1,
#   'player': 3,
#   'airport': 8,
#   'tropic': 1,
#   'actor-crooner': 1,
#   'eve': 6,
#   'armory': 1,
#   'inaugural': 3,
#   'pentagon': 12,
#   'statesman': 1,
#   'ambassador-designate': 1,
#   'decathlon': 1,
#   'ace': 1,
#   'driver': 1,
#   'comedian': 1,
#   'throw': 1,
#   'valedictorian': 1,
#   'b': 6,
#   'chancellor': 7,
#   'dean': 4,
#   'trustee': 2,
#   'geneticist': 2,
#   'prize': 10,
#   'cover': 1,
#   'idealist': 1,
#   'journal': 36,
#   'anaconda': 1,
#   'copper': 1,
#   'insurance': 3,
#   'equator': 2,
#   'secretary-general': 2,
#   'alliance': 6,
#   'progress': 7,
#   'ivory': 1,
#   'flight': 3,
#   'desert': 4,
#   'immigration': 3,
#   'border': 6,
#   'officer': 4,
#   'command': 14,
#   'turnpike': 9,
#   'toll': 1,
#   'skyway': 1,
#   'plan': 9,
#   'pact': 3,
#   'nightingale': 1,
#   'balloon': 1,
#   'sum': 1,
#   'substance': 2,
#   'power': 11,
#   'benefactor': 1,
#   'parkway': 2,
#   'cabin': 2,
#   'glen': 1,
#   'echo': 1,
#   'capital': 3,
#   'deal': 8,
#   'frontier': 5,
#   'shadow': 6,
#   'tract': 2,
#   'news': 8,
#   'stone': 7,
#   'interior': 28,
#   'construction': 1,
#   'survey': 6,
#   'side': 10,
#   'colonel': 26,
#   'presidency': 8,
#   'eagle': 1,
#   'diem': 1,
#   'charter': 12,
#   'question': 4,
#   'estimate': 4,
#   'borough': 2,
#   'hemisphere': 4,
#   'horn': 10,
#   'kingdom': 9,
#   'father': 18,
#   'loon': 1,
#   'dad': 4,
#   'rock': 17,
#   'lanesmanship': 1,
#   'curtain': 2,
#   'gazette': 9,
#   'evening': 4,
#   'prison': 2,
#   'bust': 1,
#   'wagon': 3,
#   'train': 4,
#   'car': 3,
#   'version': 6,
#   'divinity': 5,
#   'spirit': 18,
#   'sermon': 2,
#   'heaven': 16,
#   'revelation': 3,
#   'prof.': 4,
#   'wisdom': 2,
#   'volume': 18,
#   'laboratory': 13,
#   'victor': 7,
#   'homecoming': 1,
#   'grad': 1,
#   'forum': 2,
#   'problem': 1,
#   'bell': 1,
#   'knife': 2,
#   'bulletin': 11,
#   'rescue': 1,
#   'squad': 1,
#   'voice': 6,
#   'congresswoman': 1,
#   'jersey': 2,
#   'bill': 7,
#   'declaration': 15,
#   'independence': 24,
#   'speedup': 1,
#   'deep': 6,
#   'peep': 2,
#   'show': 10,
#   'legislation': 1,
#   'monument': 2,
#   'survival': 2,
#   'article': 16,
#   'member': 4,
#   'emergency': 6,
#   'session': 1,
#   'statute': 1,
#   'transit': 1,
#   'pilgrim': 1,
#   'hazel': 1,
#   'mayor-elect': 1,
#   'prayer': 4,
#   'inspector': 7,
#   'hymn': 2,
#   'fortress': 1,
#   'pearl': 4,
#   'totalitarianism': 1,
#   'nation': 21,
#   'sun': 10,
#   'professor': 28,
#   'energy': 4,
#   'guardian': 6,
#   'observer': 3,
#   'revolution': 27,
#   'restoration': 3,
#   'right': 3,
#   'telephone': 5,
#   'land': 8,
#   'magazine': 6,
#   'holiness': 1,
#   'pope': 17,
#   'catholicism': 8,
#   'unity': 5,
#   'archbishop': 6,
#   'secretariate': 1,
#   'food': 8,
#   'ethics': 5,
#   'policy': 1,
#   'principle': 1,
#   'judgment': 1,
#   'mainland': 5,
#   'duchess': 1,
#   'exegete': 1,
#   'left': 4,
#   'death': 9,
#   'face': 1,
#   'hero': 4,
#   'period': 2,
#   'adjustment': 1,
#   'taste': 1,
#   'honey': 2,
#   'hostage': 1,
#   'tenderloin': 1,
#   'do': 1,
#   're': 1,
#   'mi': 1,
#   'wildcat': 1,
#   'tree': 2,
#   'choice': 2,
#   'diary': 1,
#   'widow': 2,
#   'sesame': 1,
#   'variety': 1,
#   'textile': 2,
#   'draft': 8,
#   'program': 17,
#   'marshal': 21,
#   'lobby': 1,
#   'teaching': 1,
#   'community': 12,
#   'market': 11,
#   'philosophy': 2,
#   'flier': 1,
#   'plea': 1,
#   'sentence': 1,
#   'tractor': 1,
#   'regency': 1,
#   'liberalism': 2,
#   'confrontation': 7,
#   'interpretation': 3,
#   'neck': 2,
#   'propaganda': 1,
#   'supplement': 2,
#   'concerto': 5,
#   'overture': 4,
#   'ring': 3,
#   'lark': 1,
#   'jazz': 13,
#   'scene': 4,
#   'phase': 6,
#   'review': 10,
#   'percussion': 2,
#   'melody': 1,
#   'story': 3,
#   'information': 5,
#   'conservatory': 2,
#   'sonata': 8,
#   'a': 2,
#   'violin': 1,
#   'piano': 8,
#   'film': 1,
#   'philharmonic': 9,
#   'prelude': 2,
#   'op.': 8,
#   'e': 1,
#   'defeat': 3,
#   'victory': 6,
#   'brass': 1,
#   'choir': 4,
#   'playhouse': 4,
#   'epitaph': 3,
#   'love': 9,
#   'aunt': 12,
#   'girl': 9,
#   'politics': 2,
#   'poker': 1,
#   'tin': 1,
#   'price': 1,
#   'silence': 2,
#   'tyranny': 1,
#   'dream': 4,
#   'vocabularianism': 1,
#   'herald': 10,
#   'catfish': 2,
#   'toast': 1,
#   'bride': 1,
#   'vanguard': 2,
#   'madrigal': 1,
#   'recital': 2,
#   'globe': 1,
#   'sailor': 1,
#   'being': 3,
#   'rainbow': 2,
#   'rain': 2,
#   'shine': 1,
#   'weather': 3,
#   'baby': 5,
#   'count': 5,
#   'castle': 1,
#   'vamp': 1,
#   'evolution': 2,
#   'pony': 3,
#   'trio': 1,
#   'journey': 2,
#   'dance': 6,
#   'figure': 38,
#   'toccata': 1,
#   'young': 1,
#   'emperor': 12,
#   'nocturne': 3,
#   'crush': 1,
#   'treasure': 1,
#   'spruce': 3,
#   'milk': 1,
#   'ballad': 1,
#   'soldier': 1,
#   'cameo': 1,
#   'bourgeois': 1,
#   'gentleman': 1,
#   'invalid': 1,
#   'flea': 2,
#   'quintet': 2,
#   'swing': 2,
#   'honeysuckle': 1,
#   'rose': 2,
#   'artillery': 2,
#   'kid': 6,
#   'rag': 3,
#   'one-step': 1,
#   'parade': 1,
#   'mood': 1,
#   'bugle': 1,
#   'call': 1,
#   'triptych': 1,
#   '56a': 1,
#   'adultery': 1,
#   'nutcracker': 3,
#   'snow': 1,
#   'maiden': 1,
#   'making': 3,
#   'sponsor': 7,
#   'keystone': 1,
#   'saloon': 2,
#   'wind': 2,
#   'roof': 1,
#   'ash-can': 1,
#   'dust': 2,
#   'adagio': 1,
#   'fantasy': 2,
#   'chorus': 1,
#   'c': 1,
#   'cosmology': 1,
#   'ado': 4,
#   'rink': 2,
#   'friar': 1,
#   'design': 3,
#   'divertimento': 1,
#   'duel': 2,
#   'brother': 2,
#   'violence': 2,
#   'suite': 6,
#   'quadrille': 1,
#   'platter': 1,
#   'foliage': 1,
#   'gap': 6,
#   'iron': 4,
#   'mountain': 6,
#   'peninsula': 4,
#   'arrowhead': 1,
#   'fall': 8,
#   'color': 2,
#   'steamboat': 1,
#   'corn': 2,
#   'centennial': 3,
#   'catcher': 1,
#   'rye': 1,
#   'almanac': 1,
#   'maid': 4,
#   'mist': 1,
#   'maestro': 4,
#   'yacht': 3,
#   'hurricane': 1,
#   'isle': 1,
#   'sound': 2,
#   'labour': 1,
#   'summit': 1,
#   'lm': 1,
#   'physiologist': 1,
#   'hygiene': 1,
#   'medicine': 4,
#   'quota': 1,
#   'crucible': 1,
#   'devil': 4,
#   'scripture': 3,
#   'continent': 5,
#   'promotion': 1,
#   'octave': 2,
#   'universe': 8,
#   'oratory': 1,
#   'mass': 6,
#   'fate': 3,
#   'benediction': 1,
#   'shepherd': 1,
#   'faith': 3,
#   'nonconformist': 1,
#   'sacrifice': 1,
#   'savior': 4,
#   'will': 5,
#   'creator': 8,
#   'word': 8,
#   'lecture': 1,
#   'orthodoxy': 3,
#   'address': 1,
#   'dollar': 2,
#   'truth': 2,
#   'criticism': 1,
#   'gospel': 2,
#   'pragmatism': 1,
#   'genesis': 1,
#   'saviour': 8,
#   'head': 2,
#   'prophet': 1,
#   'psalm': 3,
#   'fear': 1,
#   'nature': 3,
#   'centrality': 3,
#   'moon': 10,
#   'northeast': 1,
#   'visitation': 2,
#   'evangelism': 2,
#   'responsibility': 1,
#   'list': 1,
#   'membership': 4,
#   'preparation': 2,
#   'assimilation': 1,
#   'reception': 3,
#   'supper': 5,
#   'pledge': 1,
#   'loyalty': 1,
#   'volunteer': 1,
#   'movement': 3,
#   'estate': 3,
#   'code': 16,
#   'realtor': 1,
#   'vineyard': 1,
#   'seminary': 8,
#   'awakening': 1,
#   'transcendentalism': 2,
#   'missionary': 2,
#   'millennium': 1,
#   'meeting': 2,
#   'infinite': 1,
#   'indulgence': 1,
#   'edition': 1,
#   'muscle': 1,
#   ...},
#  'JJ-TL': {'grand': 13,
#   'executive': 5,
#   'superior': 15,
#   'blue': 42,
#   'rural': 7,
#   'democratic': 65,
#   'deaf': 1,
#   'supreme': 31,
#   'west': 90,
#   'junior': 38,
#   'southwestern': 1,
#   'high': 28,
#   'independent': 2,
#   'new': 523,
#   'criminal': 4,
#   'white': 81,
#   'east': 94,
#   'presidential': 22,
#   'north': 94,
#   'foreign': 18,
#   'general': 76,
#   'east-west': 4,
#   'economic': 19,
#   'south': 73,
#   'national': 153,
#   'latin': 15,
#   'southeast': 16,
#   'asian': 1,
#   'royal': 18,
#   'juvenile': 3,
#   'advisory': 14,
#   'federal': 127,
#   'central': 56,
#   'legislative': 1,
#   'gen.': 4,
#   'rotary': 3,
#   'socialist': 12,
#   'american': 109,
#   'sanitary': 2,
#   'young': 8,
#   'scotch': 3,
#   'military': 10,
#   'red': 49,
#   'southern': 106,
#   'green': 8,
#   'liberal': 4,
#   'mayoral': 1,
#   'irish': 8,
#   'public': 30,
#   'northern': 23,
#   'congressional': 8,
#   'middle': 23,
#   'western': 99,
#   'administrative': 3,
#   'budgetary': 1,
#   'external': 1,
#   'elementary': 2,
#   'n.': 2,
#   'common': 8,
#   'continental': 15,
#   'deputy': 4,
#   'residential': 2,
#   'international': 34,
#   'memorial': 16,
#   'northwestern': 2,
#   'masonic': 3,
#   'old': 61,
#   'yankee': 3,
#   'fresh': 3,
#   'rosy': 1,
#   'big': 35,
#   'southwest': 5,
#   'ex-national': 1,
#   'olympic': 3,
#   'standard': 12,
#   'athletic': 4,
#   'catholic': 9,
#   'polytechnic': 1,
#   'good': 13,
#   'long': 17,
#   'metropolitan': 11,
#   'gold': 2,
#   'professional': 3,
#   'outstanding': 1,
#   "ol'": 1,
#   'italian': 4,
#   'universal-international': 1,
#   'eastern': 21,
#   'social': 15,
#   'methodist': 6,
#   'christian': 16,
#   'jewish': 8,
#   'sweet': 1,
#   'muncipal': 1,
#   'electric': 7,
#   'vocational': 5,
#   'holy': 27,
#   'revolutionary': 1,
#   'human': 2,
#   'northeast': 3,
#   'northwest': 4,
#   'e.': 1,
#   'retail': 1,
#   'scottish': 5,
#   'interstate': 9,
#   'wild': 2,
#   's.': 2,
#   'southeastern': 1,
#   'distributive': 1,
#   'pharmical': 1,
#   'under': 3,
#   'pacific': 22,
#   'chemical': 2,
#   'fundamental': 1,
#   'cerebral': 1,
#   'golden': 14,
#   'random': 1,
#   'oriental': 13,
#   'fine': 8,
#   'medical': 40,
#   'colonial': 5,
#   'jolly': 1,
#   'rusty': 1,
#   'atlantic': 13,
#   'lutheran': 2,
#   'nazarene': 1,
#   'successful': 1,
#   'episcopal': 5,
#   'gala': 1,
#   'imperial': 7,
#   'gray': 9,
#   'spangled': 1,
#   'ancient': 6,
#   'civil': 46,
#   'industrial': 26,
#   'daily': 23,
#   'french': 15,
#   'indian': 5,
#   'fair': 6,
#   'vice': 15,
#   'electoral': 2,
#   'british': 16,
#   'valuable': 1,
#   'little': 28,
#   'modern': 5,
#   'mutual': 5,
#   'belgian': 1,
#   'western-style': 1,
#   'great': 48,
#   'congolese': 3,
#   'nationalist': 1,
#   'outer': 4,
#   'strategic': 3,
#   'assistant': 9,
#   'free': 13,
#   'joint': 7,
#   'far': 6,
#   'inter-american': 1,
#   'republican': 4,
#   'iron': 2,
#   'literary': 1,
#   'elegant': 1,
#   'korean': 5,
#   'religious': 3,
#   'congregational': 7,
#   'pre-legislative': 1,
#   'prime': 5,
#   'special': 9,
#   'civilian': 1,
#   'mighty': 2,
#   'atomic': 5,
#   'dead': 1,
#   'happy': 3,
#   'cold': 8,
#   'ecumenical': 1,
#   'orthodox': 8,
#   'divine': 4,
#   'moral': 2,
#   'political': 1,
#   'algerian': 3,
#   'future': 5,
#   'unsinkable': 4,
#   'merry': 1,
#   'ionic': 2,
#   'virgin': 2,
#   'danish': 1,
#   'civic': 2,
#   'terrible': 1,
#   'all-star': 1,
#   'mad': 2,
#   'percussive': 2,
#   'minor': 9,
#   'flat': 1,
#   'baroque': 2,
#   'ceremonial': 1,
#   'musical': 4,
#   'ashmolean': 1,
#   'russian': 2,
#   'provisional': 2,
#   'quiet': 1,
#   'poor': 1,
#   'alone': 1,
#   'beautiful': 3,
#   'hard-hearted': 1,
#   'brown': 4,
#   'indeterminate': 1,
#   'orchestral': 1,
#   'titanic': 1,
#   'bright': 3,
#   'imaginary': 1,
#   'hot': 5,
#   'heavy': 1,
#   'careless': 1,
#   'weary': 1,
#   'original': 1,
#   'indigo': 1,
#   'non-dissonant': 1,
#   'choral': 1,
#   'rival': 1,
#   'canadian': 3,
#   'maritime': 3,
#   'placid': 2,
#   'upper': 5,
#   'territorial': 2,
#   'corinthian': 1,
#   'german': 3,
#   'well': 1,
#   'physiological': 1,
#   'internal': 11,
#   'puritan': 4,
#   'protestant': 5,
#   'roman': 17,
#   'anglican': 2,
#   'true': 1,
#   'redundant': 1,
#   'back': 2,
#   'calvinist': 1,
#   'mexican': 2,
#   'almighty': 2,
#   'classical': 5,
#   'chinese': 1,
#   'confucian': 2,
#   'sacred': 4,
#   'bodily': 1,
#   'near': 1,
#   'universal': 5,
#   'yellow': 1,
#   'lay': 2,
#   'local': 2,
#   'islamic': 1,
#   'rican': 1,
#   'heavenly': 1,
#   'real': 5,
#   'milky': 2,
#   'theological': 3,
#   'unitarian': 1,
#   'inner': 2,
#   'yearly': 1,
#   'scotian': 1,
#   'buddhist': 3,
#   'eternal': 3,
#   'plenary': 2,
#   'muscular': 1,
#   'straight-arm': 1,
#   'super': 1,
#   'lateral': 1,
#   'one-leg': 1,
#   'open': 2,
#   'intermediate': 2,
#   'prompt': 3,
#   'torrid': 1,
#   'majestic': 1,
#   'direct': 1,
#   'tiny': 1,
#   'brief': 1,
#   'custom': 3,
#   'meadow': 1,
#   'worthy': 1,
#   'precious': 7,
#   'prudent': 1,
#   'lucky': 1,
#   'scarlet': 2,
#   'plain': 1,
#   'dauntless': 1,
#   'clever': 1,
#   'stormy': 1,
#   'urban': 1,
#   'early': 7,
#   'dark': 10,
#   'rim-fire': 1,
#   'deluxe': 1,
#   'naval': 11,
#   'dutch': 6,
#   'silver': 1,
#   'smoky': 3,
#   'black': 16,
#   'ottoman': 2,
#   'pan': 2,
#   'turkish': 4,
#   'serpentine': 1,
#   'sunken': 1,
#   'a-1': 1,
#   'sure': 1,
#   'w.': 1,
#   "hon'ble": 2,
#   'baptist': 1,
#   'confederate': 12,
#   'geological': 6,
#   'nationalistic': 1,
#   'star-spangled': 1,
#   'lobar': 1,
#   'respiratory': 1,
#   'occupational': 1,
#   'dietetic': 1,
#   'physical': 3,
#   'outdoor': 3,
#   'advanced': 2,
#   'electrical': 5,
#   'senior': 2,
#   'tri-state': 12,
#   'round': 2,
#   'structural': 3,
#   'representative': 1,
#   'organic': 1,
#   'bio-dynamic': 1,
#   'natural': 1,
#   'on-to-spokane': 1,
#   'barre-montpelier': 1,
#   'nude': 1,
#   'ideal': 1,
#   'sexual': 1,
#   'mental': 1,
#   'pure': 1,
#   'postal': 2,
#   'correct': 1,
#   'incorrect': 1,
#   'doubtful': 1,
#   'significant': 1,
#   'final': 3,
#   'scriptural': 1,
#   'english': 7,
#   'arctic': 1,
#   'furious': 3,
#   'lousie': 1,
#   'light': 1,
#   'spanish-american': 2,
#   'historical': 1,
#   'arabian': 1,
#   'hawaiian': 3,
#   'inland': 1,
#   'geodetic': 1,
#   'regular': 4,
#   'brevet': 1,
#   'communist': 2,
#   'hungarian': 2,
#   'polish': 3,
#   'educational': 3,
#   'scientific': 4,
#   'cultural': 5,
#   'geographic': 1,
#   'peaceful': 1,
#   'nuclear': 1,
#   'active': 1,
#   'instant': 1,
#   'intercollegiate': 1,
#   'emeritus': 1,
#   'coastal': 1,
#   'bleak': 1,
#   'spanish': 6,
#   'pincian': 2,
#   'italo-american': 1,
#   'arabian-american': 1,
#   'israeli': 3,
#   'japanese': 1,
#   'waist-high': 1,
#   'deep': 1,
#   'positive': 1,
#   'ballistic': 2,
#   'municipal': 1,
#   'heroic': 1,
#   'peaceable': 1,
#   'beat': 1,
#   'european': 9,
#   'transcendental': 1,
#   'nameless': 1,
#   'immortal': 1,
#   'maltese': 2,
#   'romantic': 1,
#   'offensive': 1,
#   'un-american': 1,
#   'psychoanalytic': 1,
#   'oedipal': 1,
#   'invisible': 1,
#   'pink': 1,
#   'gothic': 3,
#   'agreeable': 3,
#   'hebrew': 2,
#   'disciplinary': 1,
#   'privy': 3,
#   'publick': 2,
#   'popish': 1,
#   'jacobite': 1,
#   'hanoverian': 2,
#   'facetious': 1,
#   'venerable': 1,
#   "li'l": 1,
#   'marvelous': 1,
#   'amen': 7,
#   'honorable': 3,
#   'personal': 1,
#   'interpersonal': 1,
#   'venetian': 1,
#   'crimean': 1,
#   'short': 2,
#   'narrow': 1,
#   'barren': 1,
#   'low': 3,
#   'bold': 1,
#   'anglo-saxon': 1,
#   'philosophical': 2,
#   'weird': 1,
#   'broad': 1,
#   'superlative': 1,
#   'greek': 2,
#   'needy': 1,
#   'drawing': 1,
#   'utopian': 1,
#   'solar': 2,
#   'loud': 1,
#   'brave': 2,
#   'hideous': 1,
#   'evergreen': 1,
#   'shy': 1,
#   'partisan': 3,
#   'critical': 1,
#   'current': 1,
#   'small': 12,
#   'regional': 4,
#   'cooperative': 2,
#   'fiscal': 1,
#   'domestic': 3,
#   'midwestern': 1,
#   'electronic': 3,
#   'med-chemical': 1,
#   'right': 1,
#   'state-local': 1,
#   'metropolian': 1,
#   'forensic': 6,
#   'ophthalmic': 2,
#   'oral': 2,
#   'cardiovasculatory': 1,
#   'orthopedic': 2,
#   'resident': 1,
#   'south-east': 1,
#   'graphic': 1,
#   'testicular': 1,
#   'clinico-pathologic': 3,
#   'macropathological': 1,
#   'temporary': 1,
#   'technical': 2,
#   'epidemiological': 1,
#   'yugoslav': 7,
#   'agricultural': 3,
#   'export-import': 14,
#   'unpaid': 1,
#   'gross': 11,
#   'taxable': 1,
#   'collegiate': 1,
#   'annual': 3,
#   'post-graduate': 1,
#   'modular': 1,
#   'full': 2,
#   'skeletal': 9,
#   'statistical': 1,
#   'multiphastic': 1,
#   'verbal': 1,
#   'basic': 1,
#   'two-stem': 1,
#   'popular': 2,
#   'mathematical': 1,
#   'substantive': 1,
#   'due': 1,
#   'judicial': 1,
#   'migrant': 1,
#   'middle-south': 2,
#   'intergroup': 1,
#   'foggy': 2,
#   'financial': 1,
#   'geometric': 16,
#   'ripe': 3,
#   'strong': 1,
#   'late': 2,
#   'co-operative': 1,
#   'hydro-electric': 1,
#   'ecclesiastical': 1,
#   'medieval': 1,
#   'know-nothing': 1,
#   'cubist': 5,
#   'analytical': 4,
#   'synthetic': 1,
#   'abstract': 1,
#   'sane': 3,
#   'private': 1,
#   'various': 1,
#   'neutral': 5,
#   'darkling': 1,
#   'madding': 1,
#   'reactionary': 1,
#   'available': 2,
#   'input/output': 4,
#   'descriptive': 1,
#   'petty': 1,
#   'crystallographic': 1,
#   'automatic': 1,
#   'distinguished': 1,
#   'purple': 1,
#   'african': 1,
#   'ole': 3,
#   'provincial': 1,
#   "death's-head": 2,
#   'ukrainian': 1,
#   'baltic': 1,
#   'wicked': 1,
#   'grassy': 1,
#   'double': 1,
#   'peerless': 3,
#   'average': 1,
#   'major': 1,
#   'muslim': 1,
#   'philippine': 1,
#   'apocalyptic': 2,
#   'veterinary': 1,
#   'underwater': 2},
#  'VBD': {'said': 1331,
#   'produced': 28,
#   'took': 365,
#   'recommended': 17,
#   'commented': 16,
#   'urged': 21,
#   'found': 236,
#   'added': 67,
#   'praised': 8,
#   'filed': 12,
#   'charged': 17,
#   'listed': 11,
#   'became': 232,
#   'announced': 49,
#   'brought': 115,
#   'attended': 24,
#   'wanted': 157,
#   'voted': 22,
#   'resigned': 7,
#   'approved': 12,
#   'opened': 82,
#   'told': 240,
#   'passed': 82,
#   'pointed': 42,
#   'rejected': 12,
#   'asked': 240,
#   'tossed': 18,
#   'put': 110,
#   'saw': 283,
#   'defeated': 5,
#   'received': 62,
#   'got': 275,
#   'stood': 161,
#   'shot': 17,
#   'scheduled': 2,
#   'feared': 9,
#   'promised': 22,
#   'made': 405,
#   'went': 406,
#   'seemed': 247,
#   'led': 78,
#   'taunted': 1,
#   'left': 133,
#   'termed': 2,
#   'drafted': 2,
#   'declared': 51,
#   'sounded': 24,
#   'argued': 15,
#   'complained': 20,
#   'estimated': 8,
#   'heard': 106,
#   'sent': 62,
#   'whipped': 6,
#   'validated': 1,
#   'enlarged': 1,
#   'amended': 3,
#   'suggested': 42,
#   'decided': 98,
#   'kept': 93,
#   'reported': 47,
#   'lost': 46,
#   'insisted': 30,
#   'ended': 39,
#   'construed': 1,
#   'felt': 235,
#   'proposed': 19,
#   'joined': 30,
#   'called': 142,
#   'startled': 3,
#   'indicated': 57,
#   'knew': 316,
#   'leaned': 27,
#   'inquired': 9,
#   'replied': 49,
#   'pushed': 27,
#   'spent': 33,
#   'talked': 26,
#   'returned': 71,
#   'involved': 22,
#   'obtained': 8,
#   'pertained': 1,
#   'ruled': 12,
#   'admitted': 22,
#   'issued': 18,
#   'questioned': 6,
#   'constituted': 7,
#   'tied': 11,
#   'sponsored': 7,
#   'noted': 25,
#   'opposed': 9,
#   'criticized': 3,
#   'backed': 20,
#   'hailed': 2,
#   'confirmed': 8,
#   'described': 25,
#   'hastened': 5,
#   'came': 522,
#   'gave': 247,
#   'agreed': 45,
#   'served': 52,
#   'shipped': 1,
#   'respected': 5,
#   'informed': 22,
#   'disclosed': 7,
#   'looked': 241,
#   'aided': 2,
#   'exposed': 4,
#   'acclaimed': 1,
#   'laid': 21,
#   'prepared': 12,
#   'disagreed': 3,
#   'expressed': 24,
#   'believed': 50,
#   'wrote': 169,
#   'advised': 13,
#   'studied': 29,
#   'steered': 3,
#   'retired': 9,
#   'transferred': 1,
#   'explained': 50,
#   'arose': 15,
#   'assured': 13,
#   'started': 113,
#   'spoke': 72,
#   'stopped': 81,
#   'congealed': 2,
#   'considered': 25,
#   'regretted': 5,
#   'launched': 3,
#   'decried': 2,
#   'saved': 10,
#   'failed': 50,
#   'transcended': 1,
#   'developed': 41,
#   'established': 9,
#   'expanded': 7,
#   'modernized': 1,
#   'introduced': 14,
#   'elected': 2,
#   'supported': 17,
#   'welled': 1,
#   'viewed': 2,
#   'regarded': 11,
#   'visited': 23,
#   'declined': 15,
#   'discovered': 24,
#   'protested': 9,
#   'shrugged': 10,
#   'remarked': 22,
#   'pulled': 45,
#   'allocated': 2,
#   'conceded': 5,
#   'concluded': 20,
#   'read': 29,
#   'turned': 209,
#   'remained': 76,
#   'continued': 77,
#   'contracted': 4,
#   'played': 59,
#   'appeared': 111,
#   'intervened': 4,
#   'paid': 42,
#   'ranged': 15,
#   'objected': 11,
#   'voiced': 4,
#   'drew': 52,
#   'raised': 36,
#   'included': 40,
#   'indorsed': 1,
#   'pleaded': 6,
#   'ran': 117,
#   'tore': 12,
#   'suffered': 19,
#   'knocked': 17,
#   'landed': 11,
#   'began': 281,
#   'offered': 37,
#   'bowed': 5,
#   'contested': 1,
#   'threatened': 15,
#   'stated': 38,
#   'cited': 11,
#   'thought': 248,
#   'examined': 9,
#   'revised': 5,
#   'stressed': 11,
#   'denied': 10,
#   'retained': 4,
#   'dropped': 61,
#   'coasted': 2,
#   'held': 109,
#   'entered': 63,
#   'needed': 49,
#   'existed': 27,
#   'stole': 7,
#   'fanned': 4,
#   'singled': 7,
#   'proved': 45,
#   'relieved': 3,
#   'performed': 11,
#   'allowed': 21,
#   'merited': 4,
#   'fielded': 1,
#   'worked': 66,
#   'popped': 5,
#   'bounced': 12,
#   'doubled': 4,
#   'moved': 121,
#   'crossed': 24,
#   'beat': 10,
#   'grabbed': 17,
#   'threw': 33,
#   'slammed': 12,
#   'tried': 100,
#   'romped': 1,
#   'blasted': 3,
#   'cut': 23,
#   'rapped': 2,
#   'ripened': 1,
#   'slugged': 3,
#   'drove': 48,
#   'flew': 26,
#   'signed': 14,
#   'checked': 10,
#   'set': 63,
#   'posted': 3,
#   'enlisted': 5,
#   'greeted': 12,
#   'headed': 22,
#   'expired': 3,
#   'arrived': 39,
#   'inflicted': 3,
#   'downed': 1,
#   'won': 45,
#   'tired': 3,
#   'bet': 1,
#   'wiped': 11,
#   'broke': 61,
#   'finished': 26,
#   'snapped': 10,
#   'injured': 2,
#   'donated': 1,
#   'lettered': 1,
#   'kicked': 10,
#   'missed': 15,
#   'carried': 52,
#   'punted': 1,
#   'caught': 40,
#   'netted': 1,
#   'gained': 18,
#   'uncorked': 1,
#   'prevailed': 6,
#   'stayed': 50,
#   'caused': 36,
#   'contributed': 24,
#   'spotted': 9,
#   'timed': 2,
#   'crucified': 1,
#   'nailed': 3,
#   'intercepted': 3,
#   'lay': 68,
#   'waited': 52,
#   'scrimmaged': 1,
#   'directed': 9,
#   'exclaimed': 12,
#   'reviewed': 3,
#   'delivered': 10,
#   'hit': 33,
#   'claimed': 24,
#   'resulted': 32,
#   'permitted': 13,
#   'combined': 6,
#   'walked': 114,
#   'lagged': 1,
#   'cracked': 9,
#   'gruonded': 1,
#   'bunched': 1,
#   'tripled': 1,
#   'accounted': 4,
#   'hammered': 3,
#   'showed': 125,
#   'eluded': 2,
#   'scored': 9,
#   'awaited': 4,
#   'learned': 52,
#   'warmed': 5,
#   'quoted': 8,
#   'embossed': 1,
#   'reached': 93,
#   'sighed': 14,
#   'waved': 16,
#   'walloped': 1,
#   'revived': 3,
#   'mounted': 10,
#   'routed': 1,
#   'smashed': 9,
#   'fizzled': 1,
#   'fouled': 2,
#   'slashed': 5,
#   'depended': 9,
#   'forced': 19,
#   'sought': 32,
#   'owned': 12,
#   'operated': 7,
#   'earned': 8,
#   'achieved': 12,
#   'endeared': 2,
#   'flubbed': 1,
#   'motivated': 1,
#   'boomed': 1,
#   'wailed': 3,
#   'sliced': 3,
#   'hooked': 1,
#   'over-corrected': 1,
#   'cost': 10,
#   'wound': 5,
#   'fell': 74,
#   'drank': 9,
#   'flowed': 4,
#   'floated': 6,
#   'picked': 38,
#   'handed': 23,
#   'confessed': 5,
#   'happened': 72,
#   'burrowed': 1,
#   'quieted': 2,
#   'jumped': 29,
#   'tumbled': 7,
#   'overcame': 2,
#   'honored': 2,
#   'dealt': 7,
#   'shared': 17,
#   'recalled': 17,
#   'doubted': 9,
#   'admired': 7,
#   'accepted': 25,
#   'presented': 15,
#   'healed': 3,
#   'compiled': 2,
#   'pitched': 3,
#   'batted': 1,
#   'belted': 2,
#   'enabled': 10,
#   'resented': 3,
#   'inherited': 5,
#   'preached': 5,
#   'bestowed': 2,
#   'taught': 17,
#   'lived': 61,
#   'met': 67,
#   'planned': 18,
#   'wheeled': 6,
#   'inflamed': 1,
#   "bulletin'd": 1,
#   'filled': 28,
#   'sold': 16,
#   'telephoned': 12,
#   'muttered': 13,
#   'sidled': 2,
#   'officiated': 3,
#   'wore': 52,
#   'seated': 2,
#   'originated': 9,
#   'entertained': 4,
#   'chose': 33,
#   'selected': 7,
#   'struck': 36,
#   'followed': 78,
#   'attempted': 18,
#   'assaulted': 3,
#   'damaged': 5,
#   'occurred': 46,
#   'used': 118,
#   'abandoned': 5,
#   'summoned': 3,
#   'resumed': 10,
#   'appointed': 8,
#   'totaled': 6,
#   'amounted': 2,
#   'predicted': 5,
#   'testified': 9,
#   'identified': 10,
#   'succeeded': 17,
#   'changed': 23,
#   'refused': 40,
#   'asserted': 11,
#   'increased': 36,
#   'demanded': 31,
#   'cleared': 11,
#   'blabbed': 1,
#   'preceded': 8,
#   'posed': 3,
#   'adjourned': 2,
#   'boarded': 2,
#   'related': 9,
#   'accosted': 1,
#   'ensued': 4,
#   'fled': 21,
#   'appealed': 9,
#   'commuted': 1,
#   'skidded': 2,
#   'sped': 8,
#   'spun': 10,
#   'violated': 2,
#   'traveled': 12,
#   'died': 58,
#   'killed': 31,
#   'assumed': 23,
#   'rested': 11,
#   'fueled': 1,
#   'lacked': 15,
#   'escaped': 7,
#   'staggered': 9,
#   'surprised': 9,
#   'revealed': 19,
#   'ordered': 26,
#   'watched': 57,
#   'pursued': 3,
#   'recognized': 27,
#   'disbanded': 1,
#   'slid': 15,
#   'renewed': 2,
#   'hoped': 26,
#   'arrested': 4,
#   'ripped': 4,
# ...
#   'bona': 1,
#   'festivus': 2,
#   'salutaris': 1,
#   'colles': 1,
#   'ostinato': 1,
#   'juste': 1,
#   'eummelihs': 1,
#   'formidable': 1,
#   'merveilleux': 1,
#   'petit': 1,
#   'matinals': 1,
#   'noir': 1,
#   'schwarzen': 1},
#  'BED*': {"weren't": 12},
#  'RB+BEZ': {"here's": 8, "there's": 1},
#  'VB+PPO': {"let's": 52, 'lemme': 1, 'gimme': 1},
#  'PPSS-HL': {'we': 20, 'they': 2, 'you': 1, 'i': 2},
#  'HVZ*': {"hasn't": 15, "ain't": 1},
#  'FW-IN+NN-TL': {"d'art": 1, "d'argent": 1},
#  'FW-IN+AT-TL': {'du': 8, 'des': 4, 'della': 2, 'aux': 1, 'zur': 1},
#  'NN-NC': {'ova': 1,
#   'eva': 1,
#   'aya': 1,
#   'intellectual': 1,
#   'word': 1,
#   'herd': 1,
#   'hoof': 1,
#   'range': 1,
#   'delivery': 1,
#   'rustler': 1,
#   'hustler': 1,
#   'execution': 1,
#   'technology': 1,
#   'humly': 1,
#   'fatboy': 1,
#   'renewal': 1,
#   'idea': 2,
#   'seduction': 1,
#   'rape': 1,
#   'abortion': 1,
#   'assault': 1,
#   'wedlock': 1,
#   'mountain': 1,
#   'friendship': 1,
#   'tragedy': 1,
#   'poetry-and-jazz': 1,
#   'reading': 1,
#   'water': 9,
#   'commerce': 1,
#   'return': 1,
#   'trial': 1,
#   'experiment': 1,
#   'success': 1,
#   'failure': 1,
#   'form': 1,
#   'occurrence': 1,
#   'charge': 1,
#   'fy': 1,
#   'chair': 2,
#   'thing': 5,
#   'small-town': 1,
#   'town': 2,
#   'linguist': 4,
#   'luggage': 4,
#   'noise': 2,
#   'cat': 2,
#   'news': 1,
#   'neighborhood': 1,
#   'work': 1,
#   'child': 1,
#   'boy': 1,
#   'garage': 1,
#   'account': 1,
#   'trip': 2,
#   'hunger': 2,
#   'man': 2,
#   'paper': 2,
#   'leader': 3,
#   'camp': 2,
#   'suggestion': 1,
#   'boat': 1,
#   'conclusion': 2,
#   'consciousness': 1,
#   'moment': 2,
#   'place': 1,
#   'number': 2,
#   'chimney': 2,
#   'republic': 1,
#   'positivism': 1,
#   'mass': 1,
#   'communism': 1,
#   'alienation': 2,
#   'capitalism': 1,
#   'disaffiliation': 1,
#   'sterilization': 1,
#   'distance': 1,
#   'home': 4,
#   'eromonga': 1,
#   'commodore': 1},
#  'JJ-NC': {'dull': 1,
#   'using': 2,
#   'approximate': 1,
#   'tough': 1,
#   'violent': 1,
#   'criminal': 1,
#   'saline': 1,
#   'poor': 1,
#   'binomial': 1,
#   'true': 1,
#   'false': 1,
#   'welcome': 1,
#   'wrong': 1,
#   'friendly': 2,
#   'young': 2,
#   'pretty': 2,
#   'incredible': 2,
#   'chinese': 1,
#   'japanese': 2,
#   'afraid': 1,
#   'busy': 1,
#   'real': 2,
#   'serious': 2,
#   'gay': 2,
#   'frivolous': 1,
#   'solemn': 1,
#   'deliberate': 1,
#   'reactionary': 1,
#   'sweet': 2},
#  'NR$-TL': {"west's": 3, "today's": 3, "south's": 5},
#  'FW-PP$-NC': {'mea': 1},
#  'FW-VB': {'nolo': 1,
#   'vive': 1,
#   'fermate': 1,
#   'faciunt': 1,
#   'esse': 1,
#   'vade': 2,
#   'noli': 1,
#   'tangere': 1,
#   'dites': 1,
#   "mach't": 1,
#   'duces': 1,
#   'meminisse': 1,
#   'iuvabit': 1,
#   'gosaimasu': 1,
#   'voulez': 1,
#   'habla': 1,
#   "dabhumaksanigalu'ahai": 1,
#   "ksu'u'peli'afo": 1,
#   'lacheln': 1},
#  'FW-VB-NC': {'contendere': 1, 'esse': 1},
#  'JJR-NC': {'calmer': 1, 'smaller': 1, 'friendlier': 1, 'stranger': 2},
#  'NPS$-TL': {"yankees'": 1},
#  'QL-TL': {'most': 2, 'almost': 1, 'especially': 1, 'so': 1, 'too': 1},
#  'FW-AT': {'la': 6, 'le': 8, 'die': 4, 'ein': 2, 'keine': 1, 'eine': 1},
#  'FW-*': {'pas': 1, 'non': 3},
#  'FW-CD': {'une': 1, 'cinq': 1, 'deux': 4, 'sieben': 1},
#  'WQL': {'however': 32, 'how': 143},
#  'FW-WDT': {'quo': 11, 'qua': 2, 'quod': 1, 'que': 1},
#  'WDT+BEZ': {"what's": 33},
#  'PPO-HL': {'us': 2, 'you': 1, 'it': 1, 'them': 1},
#  'JJ-TL-HL': {'national': 2,
#   'new': 2,
#   'east': 2,
#   'bright': 1,
#   'southeast': 1,
#   'dark': 1,
#   'rural': 1,
#   'free': 1,
#   'purple': 1,
#   'international': 1,
#   'federal': 3,
#   'confederate': 1,
#   'hon.': 4,
#   'maritime': 1,
#   'medical': 3,
#   'red': 1},
#  'NPS$-HL': {"democrats'": 1},
#  'UH-HL': {'goodby': 1},
#  'WRB-HL': {'when': 5, 'why': 4, 'how': 21, 'where': 6},
#  'WDT+BEZ-HL': {"what's": 1},
#  'NP$-HL': {"u.n.'s": 1, "conant's": 3, "peabody's": 1, "wright's": 2},
#  'WDT-HL': {'what': 29, 'which': 1},
#  'DOZ-HL': {'does': 16},
#  'RB-NC': {'yes': 2,
#   'importunately': 1,
#   'perhaps': 1,
#   'out': 1,
#   'now': 3,
#   'emotionally': 2,
#   'here': 6,
#   'rarely': 2,
#   'then': 3,
#   'too': 1,
#   'no': 3,
#   'eventshah-leh': 1},
#  '---HL': {'--': 26},
#  'PP$-HL': {'our': 3, 'your': 4, 'its': 3},
#  ':-TL': {':': 22},
#  'RN': {'here': 2, 'afar': 2, 'then': 3},
#  'VBZ-TL': {'faces': 1,
#   'objects': 1,
#   'loses': 1,
#   'drifts': 1,
#   'sez': 1,
#   'meets': 1,
#   'cares': 1,
#   'means': 2,
#   'resolves': 1,
#   'rises': 1,
#   'follows': 1,
#   'comes': 2,
#   'stops': 1,
#   'wakes': 1,
#   'writes': 1},
#  'FW-PPL': {'se': 9},
#  'WPO-TL': {'whom': 1, 'what': 3},
#  'NRS': {'sundays': 8,
#   'mondays': 1,
#   'saturdays': 1,
#   'wednesdays': 1,
#   'fridays': 3},
#  'BEZ-TL': {'is': 7},
#  'PPO-TL': {'me': 7, 'it': 2, 'you': 2, 'us': 1, 'him': 1},
#  'ABN-TL': {'all': 6},
#  'FW-NP': {'karshilama': 1, 'dieu': 1, 'espanol': 1},
#  'PPL-HL': {'himself': 1},
#  'PPSS-TL': {'we': 4, 'you': 4, 'they': 1},
#  'IN-NC': {'in': 2,
#   'on': 6,
#   'with': 4,
#   'of': 3,
#   'for': 3,
#   'at': 4,
#   'than': 1,
#   'to': 8,
#   'by': 4,
#   'without': 4,
#   'up': 2},
#  'FW-VBZ': {'gouverne': 1, 'sinkt': 1, 'sigue': 1},
#  'FW-PPO': {'lui': 1, 'me': 1, 'moi': 1},
#  'DO-TL': {'do': 4},
#  'QL-HL': {'too': 1, 'naturally': 1, 'well': 1, 'much': 1},
#  'DT-TL': {'that': 4, 'this': 4},
#  'FW-NNS-TL': {'variations': 1,
#   'sonates': 1,
#   'concerts': 1,
#   'maitres': 1,
#   'siecles': 1,
#   'noces': 1,
#   'recherches': 1,
#   'forces': 2,
#   'crus': 3,
#   'femmes': 1,
#   'beaux-arts': 1,
#   'vandringsar': 1,
#   'hovdingar': 1,
#   'revolutionibus': 3,
#   'clericis': 1,
#   'laicos': 1,
#   'notitia': 1,
#   'principia': 1,
#   'planeten': 1,
#   'amici': 1,
#   'affaires': 1,
#   'indigenes': 1,
#   'commercants': 1,
#   'industrialistes': 1,
#   'artisans': 1,
#   'tabellen': 1,
#   'kristallstrukturen': 1,
#   'putas': 1,
#   'nozze': 1},
#  'FW-VBD-TL': {'stabat': 1},
#  'WRB+BEZ-TL': {"where's": 3},
#  'WRB-TL': {'where': 5, 'when': 4},
#  'WQL-TL': {'how': 5},
#  'FW-CC-TL': {'et': 8, 'ma': 1, 'och': 2, 'und': 1},
#  'FW-AT+NP-TL': {"l'astree": 1, "l'imperiale": 1},
#  'FW-OD-TL': {'18e': 2, '17e': 1},
#  'FW-AT+NN-TL': {"l'orchestre": 1,
#   "l'identite": 1,
#   "l'arcade": 1,
#   "l'ange": 1,
#   "l'assistance": 1,
#   "l'activite": 1,
#   "l'institut": 1,
#   "l'universite": 1,
#   "l'independance": 1,
#   "l'union": 2,
#   "l'unita": 1,
#   "l'osservatore": 1},
#  'NIL': {'ld': 1,
#   'has': 1,
#   'made': 3,
#   'about': 1,
#   'his': 2,
#   'pamphlet': 1,
#   'on': 2,
#   'dunkirk': 1,
#   'and': 3,
#   'crisis': 1,
#   'then': 1,
#   'he': 2,
#   'launches': 1,
#   'into': 3,
#   'an': 2,
#   'attack': 1,
#   'the': 3,
#   'tory': 1,
#   'ministers': 1,
#   'whom': 1,
#   'calls': 1,
#   'neighborhood': 1,
#   'i': 1,
#   'had': 1,
#   'many': 1,
#   'friends': 1,
#   'among': 1,
#   'them': 1,
#   'taking': 1,
#   'part': 1,
#   'in': 3,
#   'their': 1,
#   'after-school': 1,
#   'games': 1,
#   'trying': 1,
#   'desperately': 1,
#   'to': 3,
#   'translate': 1,
#   "grimm's": 1,
#   'fairy': 1,
#   'tales': 1,
#   'ij': 1,
#   'faires': 1,
#   'more': 1,
#   'what-will-t.': 1,
#   's.': 1,
#   'eliot-or-martin': 1,
#   'buber-think': 1,
#   'even': 1,
#   'years': 1,
#   'before': 1,
#   'construction': 1,
#   'can': 1,
#   'commence': 1,
#   'thus': 1,
#   'as': 1,
#   'a': 3,
#   'development': 1,
#   'program': 1,
#   'is': 1,
#   'being': 1,
#   'launched': 1,
#   'commitments': 1,
#   'obligations': 1,
#   'must': 1,
#   'be': 2,
#   'entered': 1,
#   'given': 1,
#   'year': 2,
#   'which': 1,
#   'may': 1,
#   'exceed': 1,
#   'by': 1,
#   'twofold': 1,
#   'or': 1,
#   'threefold': 1,
#   'expenditures': 1,
#   'that': 1,
#   'af': 1,
#   '?': 1,
#   'if': 1,
#   'bianco': 1,
#   'sangiovanni': 1,
#   'fresco': 1,
#   ':': 1,
#   '(': 10,
#   'b.t.u./sq.': 1,
#   'ft.': 1,
#   'of': 2,
#   'material/hr./*0f./in.': 1,
#   'thickness': 1,
#   ')': 10,
#   '29': 1,
#   '-': 6,
#   '32-degrees-c': 1,
#   '32*0c.': 1,
#   '38*0': 1,
#   '60*0c.': 1,
#   '135*0c.': 1,
#   '49*0': 1,
#   '71*&0c.': 1,
#   'measuring': 1,
#   'scale': 1,
#   '--': 1,
#   '38': 4,
#   '43*0c.': 2,
#   '43*0': 1,
#   'c.': 1,
#   '43*0c': 1},
#  'FW-IN+AT-T': {'des': 3},
#  'PPSS+BER-TL': {"you're": 1},
#  'WPS-TL': {'who': 3, 'that': 3, 'what': 5},
#  'HVZ-TL': {'has': 4},
#  'BEN-TL': {'been': 2},
#  'RP-TL': {'on': 1, 'up': 3},
#  'CD-TL-HL': {'three': 1,
#   '1': 5,
#   '4': 2,
#   '5': 1,
#   '8': 2,
#   '6': 2,
#   '7': 1,
#   '9': 1,
#   '12': 1,
#   '10': 1},
#  'BE-TL': {'be': 1},
#  'IN-TL-HL': {'of': 6},
#  'HV*': {"haven't": 24, "ain't": 4},
#  'CS-TL': {'after': 1, 'as': 1},
#  'PPSS+HV-TL': {"you've": 1},
#  'DOD*-TL': {"didn't": 1},
#  'PPS-TL': {'he': 1, 'it': 5},
#  'FW-RB-TL': {',': 1, 'bas': 1, 'assai': 1},
#  'PN-TL': {'nothing': 2, 'something': 1, 'anything': 1, 'somebody': 1},
#  'WDT+BEZ-TL': {"what's": 1},
#  'NR-TL-HL': {'west': 2, 'northeast': 2, 'south': 1},
#  'CC-TL-HL': {'and': 2},
#  'AT-TL-HL': {'a': 4, 'the': 1},
#  'FW-JJ-NC': {'sterios': 1, 'demographiques': 1},
#  'FW-JJR': {'fortiori': 1},
#  'FW-NN$': {'corporis': 1,
#   'intellectus': 1,
#   'aeternitatis': 1,
#   'senioritatis': 2,
#   'curiae': 2,
#   "patronne's": 1,
#   "chambre's": 1},
#  'FW-VBD': {'peccavi': 1, 'audivi': 1},
#  ',-TL': {',': 4},
#  'HV-HL': {'have': 3},
#  'VB+IN': {'lookit': 3},
#  'WDT+BER+PP': {'whaddya': 1},
#  'VBG+TO': {'gonna': 5},
#  'NN+HVZ': {"guy's": 1, "boat's": 1},
#  'VBN+TO': {'gotta': 4},
#  'FW-NN$-TL': {"arte's": 1, 'dei': 2, 'curiae': 1},
#  'FW-*-TL': {'non': 2},
#  'NN+BEZ': {"water's": 1,
#   "camera's": 1,
#   "sky's": 2,
#   "kid's": 3,
#   "heat's": 1,
#   "throat's": 1,
#   "father's": 1,
#   "bastard's": 1,
#   "money's": 1,
#   "undersecretary's": 1,
#   "granite's": 1,
#   "level's": 1,
#   "wife's": 1,
#   "fat's": 1,
#   "company's": 1,
#   "fire's": 2,
#   "name's": 1,
#   "hell's": 1,
#   "leg's": 1},
#  'FW-UH-NC': {'sayonara': 1},
#  'DO*-HL': {"don't": 3},
#  'PPS-HL': {'it': 18, 'he': 1},
#  'FW-PP$': {'mon': 1, 'mea': 1, 'vos': 1},
#  'RB+BEZ-HL': {"here's": 1},
#  'JJS-HL': {'top': 1},
#  'DTS-HL': {'these': 1, 'those': 1},
#  'NNS-NC': {'emeralds': 2,
#   "tailin's": 1,
#   'people': 6,
#   'women': 1,
#   'things': 3,
#   'friends': 3,
#   'sisters': 2,
#   'suggestions': 1,
#   'instructions': 4,
#   'lives': 1,
#   'relatives': 2},
#  'PPSS-NC': {'you': 7, 'i': 24},
#  'PPS-NC': {'he': 3, 'she': 3, 'it': 3},
#  'PN-NC': {'everybody': 1, 'one': 1},
#  'FW-RB': {'deja': 7,
#   'um': 1,
#   'wiederum': 1,
#   'cito': 1,
#   'velociter': 1,
#   'vielleicht': 1,
#   'simpliciter': 1,
#   'alors': 2,
#   'non': 1,
#   'zu': 1,
#   'domi': 1,
#   'nuper': 1,
#   'sic': 2,
#   'forsan': 1,
#   'olim': 1,
#   'oui': 2,
#   'semper': 1,
#   'tout': 1,
#   'despues': 1},
#  'FW-VBN': {'vue': 7, 'verstrichen': 1, 'rasa': 2, 'verboten': 1},
#  'PPL-TL': {'myself': 1},
#  'WDT+HVZ': {"what's": 2},
#  'WRB+BEZ': {"how's": 5, "where's": 3},
#  'WPS+MD': {"who'll": 1, "that'd": 1, "who'd": 3, "that'll": 2},
#  'NP-NC': {'garryowen': 1,
#   'buckman': 1,
#   'george': 6,
#   'chinese': 1,
#   'mary': 3,
#   'jack': 2,
#   'martinique': 1},
#  'FW-IN+NP-TL': {"d'yquem": 1},
#  'VBN-NC': {'mixed': 1,
#   'refreshed': 1,
#   'born': 1,
#   'broken': 3,
#   'finished': 2,
#   'made': 1},
#  'AT-NC': {'the': 26, 'a': 8, 'an': 1},
#  'FW-NN-NC': {'wohaw': 1,
#   'nisf-i-jahan': 1,
#   'aspis': 1,
#   'sakos': 1,
#   'strukturbericht': 1},
#  'NN+MD': {"cowhand'd": 1, "sun'll": 1},
#  'JJR+CS': {"lighter'n": 1},
#  'FW-NNS-NC': {'sabinas': 1, 'enquetes': 1},
#  'PPS+HVD': {"she'd": 16, "he'd": 33, "it'd": 1},
#  'VB+RP': {"g'ahn": 1},
#  'NRS-TL': {'souths': 1},
#  'FW-BEZ': {'ist': 1, 'est': 2},
#  'FW-BER': {'sind': 1, 'sunt': 1, 'etes': 1},
#  'FW-VBG': {'nolens': 1,
#   'volens': 1,
#   'appellant': 1,
#   'seq.': 1,
#   'servanda': 1,
#   'dicendi': 1},
#  'FW-NR-TL': {'heute': 1, 'morgen': 1, 'hoy': 1},
#  'FW-PPSS': {'ich': 1, 'vous': 3, 'sie': 1},
#  'FW-HV': {'habe': 1},
#  'FW-NP-TL': {'rundfunk': 1, 'afrique': 1, 'afrika': 1},
#  'VB-NC': {'trust': 1,
#   'cheat': 1,
#   'get': 1,
#   'say': 1,
#   'thank': 1,
#   'want': 1,
#   'go': 8,
#   'keep': 1,
#   'glorify': 1,
#   'know': 4,
#   'tell': 5,
#   'eat': 2,
#   'board': 1,
#   'leave': 4,
#   'come': 2,
#   'drink': 1,
#   'deal': 3,
#   'sure': 1,
#   "'nuff": 1,
#   'wait': 1},
#  'DOZ*-TL': {"doesn't": 1},
#  'FW-NPS-TL': {'svenskarna': 1},
#  'FW-PP$-TL': {'deras': 1},
#  'FW-CS': {'bevor': 1, 'quam': 1},
#  '*-TL': {'not': 1},
#  'HV-TL': {'have': 3},
#  'FW-PN': {'hoc': 1},
#  'FW-PPO+IN': {'mecum': 2, 'tecum': 1},
#  'DT-NC': {'that': 6, 'this': 1},
#  'JJT-TL': {'greatest': 1, 'highest': 1, 'youngest': 1},
#  'DTI-TL': {'any': 1, 'some': 1},
#  '.-TL': {'?': 2},
#  'EX+MD': {"there'll": 2, "there'd": 1},
#  'FW-UH': {'bien': 1,
#   'adieu': 1,
#   'arigato': 1,
#   'bonjour': 1,
#   'adios': 1,
#   'bueno': 1,
#   'tchalo': 1},
#  'FW-NPS': {'atlantes': 1, 'dieux': 1},
#  'FW-CD-TL': {'unam': 1, 'zwei': 1},
#  'FW-BE': {'sit': 1},
#  'FW-PPS': {'il': 1},
#  'FW-NR': {"aujourd'hui": 1},
#  'FW-TO+VB': {"d'entretenir": 1},
#  'FW-IN+AT': {'des': 1, 'du': 2},
#  'JJ$-TL': {"great's": 1},
#  'FW-VB-TL': {'pati': 1},
#  'FW-RB+CC': {'forisque': 1},
#  'FW-WPO': {'quibusdam': 1},
#  'FW-NN-TL-NC': {'domina': 1},
#  'FW-WPS': {'qui': 1},
#  'FW-PPL+VBZ': {"s'excuse": 1, "s'accuse": 1},
#  'DOZ-TL': {'does': 2},
#  'VBN-TL-NC': {'united': 3},
#  'NNS-TL-NC': {'states': 3},
#  'NN-TL-NC': {'state': 3},
#  'FW-DTS': {'haec': 1},
#  'NNS$-TL-HL': {"women's": 1},
#  'FW-VBG-TL': {'obliterans': 1},
#  'EX-HL': {'there': 1},
#  'PPO-NC': {'you': 4, 'him': 4, 'it': 1},
#  'PPSS+BER-N': {"you're": 1},
#  'WRB-NC': {'how': 2, 'why': 3, 'when': 2},
#  'BER-NC': {'are': 5},
#  'TO-NC': {'to': 13},
#  'NR-NC': {'home': 1, 'tuesday': 3},
#  'UH-NC': {'hello': 1, 'farewell': 1, 'hurrah': 2, 'fiddlesticks': 1},
#  'HV-NC': {'have': 11},
#  ',-NC': {',': 5},
#  'WDT+BEZ-NC': {"what's": 2},
#  '.-NC': {'?': 16},
#  'NP+HVZ-NC': {"bill's": 1},
#  'HVZ-NC': {'has': 2},
#  'CD-NC': {'one': 5},
#  'QL-NC': {'very': 2},
#  'WPS+BEZ-NC': {"who's": 2},
#  'PP$-NC': {'her': 4, 'our': 1, 'his': 8},
#  'DT+BEZ-NC': {"that's": 1},
#  'RB+BEZ-NC': {"there's": 1},
#  'WDT-NC': {'what': 4, 'which': 3},
#  'BEDZ-NC': {'was': 8},
#  'VBD-NC': {'put': 1,
#   'knew': 1,
#   'wrote': 2,
#   'came': 4,
#   'wanted': 1,
#   'looked': 2},
#  'RP-NC': {'out': 2, 'in': 2, 'up': 1},
#  'VBZ-NC': {'reads': 1, 'snows': 4, 'stimulates': 2},
#  'VBG-NC': {'looking': 1,
#   'painting': 1,
#   'hurting': 2,
#   'reading': 2,
#   'drinking': 7,
#   'visiting': 2,
#   'filling': 1},
#  'PPSS+MD-NC': {"i'll": 2},
#  '*-NC': {'not': 1},
#  'EX-NC': {'there': 1},
#  'BER*-NC': {"aren't": 1},
#  'AP-NC': {'many': 1, 'few': 1},
#  'DO-NC': {'do': 2},
#  'BED-NC': {'were': 3},
#  'CC-NC': {'and': 1, 'or': 1, 'but': 3},
#  'PPS+BEZ-NC': {"it's": 1, "he's": 2},
#  'MD-NC': {'can': 1, 'shall': 1},
#  'PPSS+BER-NC': {"we're": 1},
#  'CS-NC': {'than': 2, 'that': 2, 'unless': 1},
#  'NNS$-NC': {"sisters'": 2},
#  'PPL-NC': {'himself': 2},
#  'RBR-NC': {'more': 1},
#  'BEZ-NC': {'is': 5},
#  'OD-NC': {'first': 1},
#  'NP+BEZ-NC': {"mack's": 2, "jack's": 1},
#  'ABN-NC': {'all': 1},
#  'WPS-NC': {'that': 3},
#  'JJT-NC': {'silliest': 1},
#  'DOD-NC': {'did': 1},
#  'WPO-NC': {'that': 1},
#  'BEM-NC': {'am': 2},
#  'NPS-NC': {'steiners': 1, 'gar-dene': 1},
#  'NN+NN-NC': {'stomach-belly': 1},
#  'JJ+JJ-NC': {'big-large': 1, 'long-far': 1},
#  'AP+AP-NC': {'many-much': 1},
#  'VB+JJ-NC': {'die-dead': 1},
#  'VB+VB-NC': {'say-speak': 1},
#  'WPS-HL': {'that': 2},
#  'FW-QL': {'minus': 1},
#  'JJ-TL-NC': {'utopian': 1},
#  'FW-JJT': {'optimo': 1},
#  'WPS+BEZ-TL': {"who's": 1},
#  'HVG-HL': {'having': 1},
#  'FW-DT+BEZ': {"c'est": 2},
#  'EX+HVD': {"there'd": 3},
#  'WPS+HVZ': {"who's": 1, "that's": 1},
#  'PN+MD': {"someone'll": 1, "somebody'll": 1, "anybody'd": 1},
#  'VB+TO': {'wanta': 1, 'wanna': 1},
#  'DT+MD': {"that'll": 1},
#  'HV+TO': {'hafta': 3},
#  'MD+TO': {'oughta': 1},
#  'MD+PPSS': {'willya': 1},
#  'NR+MD': {"today'll": 1},
#  'NN+IN': {'buncha': 1},
#  'RP+IN': {"out'n": 2},
#  'BEM*': {"ain't": 9},
#  'PN+BEZ': {"nothing's": 1, "everything's": 2, "somebody's": 1, "nobody's": 1},
#  'WPS+HVD': {"who'd": 3},
#  'NN+HVD-TL': {"pa'd": 1},
#  'WDT+DOD': {"what'd": 1},
#  'NN+BEZ-TL': {"pa's": 1, "knife's": 1},
#  'WRB+DO': {'howda': 1},
#  'WRB+IN': {"why'n": 1},
#  'NP+HVZ': {"guardino's": 1,
#   "celie's": 1,
#   "skolman's": 1,
#   "crosson's": 1,
#   "tim's": 1},
#  'WRB+DOD': {"where'd": 2, "how'd": 3},
#  'WRB+MD': {"where'd": 1},
#  'EX+HVZ': {"there's": 2},
#  'NN+HVZ-TL': {"knife's": 1},
#  'PPSS+VB': {"y'know": 1},
#  'WRB+BER': {"where're": 1},
#  'NNS+MD': {"duds'd": 1},
#  'PPSS+BEZ': {"you's": 1},
#  'PPSS+BEZ*': {"'tain't": 1},
#  'RBR+CS': {"more'n": 1},
#  'NP+MD': {"gyp'll": 1},
#  'TO+VB': {"t'jawn": 1, "t'lah": 1},
#  'IN+PPO': {"t'hi-im": 1},
#  'IN+IN': {"f'ovuh": 1},
#  'DO+PPSS': {"d'you": 1},
#  'VB+AT': {'wanna': 1},
#  'WRB+DOZ': {"how's": 1},
#  'DTS+BEZ': {"them's": 1},
#  'WDT+DO+PPS': {'whaddya': 1},
#  'RB+CS': {"well's": 1}}

# %%
#Calculating the emission probabilities using train_word_tag
train_emission_prob={}
for k in train_word_tag.keys():
  train_emission_prob[k]={}
  count = sum(train_word_tag[k].values())
  for k2 in train_word_tag[k].keys():
    train_emission_prob[k][k2]=train_word_tag[k][k2]/count
train_emission_prob
# Out:
# {'##': {'##': 1.0},
#  'AT': {'the': 0.7097017949251476,
#   'an': 0.037847842037825936,
#   'no': 0.018058764907515908,
#   'a': 0.22949634772704872,
#   'every': 0.004884299059279621,
#   "th'": 1.0951343182241303e-05},
#  'NP-TL': {'fulton': 0.0025886616619207868,
#   'atlanta': 0.0010354646647683149,
#   'grady': 0.0010354646647683149,
#   'georgia': 0.0036241263266891016,
#   'jackson': 0.0005177323323841574,
#   'miller': 0.0005177323323841574,
#   'colquitt': 0.0002588661661920787,
#   'texas': 0.004400724825265338,
#   'dallas': 0.003365260160497023,
#   'beaumont': 0.0002588661661920787,
#   'lamar': 0.0005177323323841574,
#   'texan': 0.0002588661661920787,
#   'wise': 0.0002588661661920787,
#   'paris': 0.000776598498576236,
#   'oklahoma': 0.000776598498576236,
#   'rhode': 0.02562775045301579,
#   'massachusetts': 0.0036241263266891016,
#   'u.s.': 0.014496505306756407,
#   'denton': 0.0002588661661920787,
#   'york': 0.07377685736474243,
#   'st.': 0.0028475278281128655,
#   'louis': 0.003365260160497023,
#   'cook': 0.0005177323323841574,
#   'republican': 0.0023297954957287085,
#   'atlantic': 0.001553196997152472,
#   'viet': 0.0025886616619207868,
#   ':': 0.006369426751592357,
#   '(': 0.06369426751592357,
#   'b.t.u./sq.': 0.006369426751592357,
#   'ft.': 0.006369426751592357,
#   'of': 0.012738853503184714,
#   'material/hr./*0f./in.': 0.006369426751592357,
#   'thickness': 0.006369426751592357,
#   ')': 0.06369426751592357,
#   '29': 0.006369426751592357,
#   '-': 0.03821656050955414,
#   '32-degrees-c': 0.006369426751592357,
#   '32*0c.': 0.006369426751592357,
#   '38*0': 0.006369426751592357,
#   '60*0c.': 0.006369426751592357,
#   '135*0c.': 0.006369426751592357,
#   '49*0': 0.006369426751592357,
#   '71*&0c.': 0.006369426751592357,
#   'measuring': 0.006369426751592357,
#   'scale': 0.006369426751592357,
#   '--': 0.006369426751592357,
#   '38': 0.025477707006369428,
#   '43*0c.': 0.012738853503184714,
#   '43*0': 0.006369426751592357,
#   'c.': 0.006369426751592357,
#   '43*0c': 0.006369426751592357},
#  'FW-IN+AT-T': {'des': 1.0},
#  'PPSS+BER-TL': {"you're": 1.0},
#  'WPS-TL': {'who': 0.2727272727272727,
#   'that': 0.2727272727272727,
#   'what': 0.45454545454545453},
#  'HVZ-TL': {'has': 1.0},
#  'BEN-TL': {'been': 1.0},
#  'RP-TL': {'on': 0.25, 'up': 0.75},
#  'CD-TL-HL': {'three': 0.058823529411764705,
#   '1': 0.29411764705882354,
#   '4': 0.11764705882352941,
#   '5': 0.058823529411764705,
#   '8': 0.11764705882352941,
#   '6': 0.11764705882352941,
#   '7': 0.058823529411764705,
#   '9': 0.058823529411764705,
#   '12': 0.058823529411764705,
#   '10': 0.058823529411764705},
#  'BE-TL': {'be': 1.0},
#  'IN-TL-HL': {'of': 1.0},
#  'HV*': {"haven't": 0.8571428571428571, "ain't": 0.14285714285714285},
#  'CS-TL': {'after': 0.5, 'as': 0.5},
#  'PPSS+HV-TL': {"you've": 1.0},
#  'DOD*-TL': {"didn't": 1.0},
#  'PPS-TL': {'he': 0.16666666666666666, 'it': 0.8333333333333334},
#  'FW-RB-TL': {',': 0.3333333333333333,
#   'bas': 0.3333333333333333,
#   'assai': 0.3333333333333333},
#  'PN-TL': {'nothing': 0.4, 'something': 0.2, 'anything': 0.2, 'somebody': 0.2},
#  'WDT+BEZ-TL': {"what's": 1.0},
#  'NR-TL-HL': {'west': 0.4, 'northeast': 0.4, 'south': 0.2},
#  'CC-TL-HL': {'and': 1.0},
#  'AT-TL-HL': {'a': 0.8, 'the': 0.2},
#  'FW-JJ-NC': {'sterios': 0.5, 'demographiques': 0.5},
#  'FW-JJR': {'fortiori': 1.0},
#  'FW-NN$': {'corporis': 0.1111111111111111,
#   'intellectus': 0.1111111111111111,
#   'aeternitatis': 0.1111111111111111,
#   'senioritatis': 0.2222222222222222,
#   'curiae': 0.2222222222222222,
#   "patronne's": 0.1111111111111111,
#   "chambre's": 0.1111111111111111},
#  'FW-VBD': {'peccavi': 0.5, 'audivi': 0.5},
#  ',-TL': {',': 1.0},
#  'HV-HL': {'have': 1.0},
#  'VB+IN': {'lookit': 1.0},
#  'WDT+BER+PP': {'whaddya': 1.0},
#  'VBG+TO': {'gonna': 1.0},
#  'NN+HVZ': {"guy's": 0.5, "boat's": 0.5},
#  'VBN+TO': {'gotta': 1.0},
#  'FW-NN$-TL': {"arte's": 0.25, 'dei': 0.5, 'curiae': 0.25},
#  'FW-*-TL': {'non': 1.0},
#  'NN+BEZ': {"water's": 0.043478260869565216,
#   "camera's": 0.043478260869565216,
#   "sky's": 0.08695652173913043,
#   "kid's": 0.13043478260869565,
#   "heat's": 0.043478260869565216,
#   "throat's": 0.043478260869565216,
#   "father's": 0.043478260869565216,
#   "bastard's": 0.043478260869565216,
#   "money's": 0.043478260869565216,
#   "undersecretary's": 0.043478260869565216,
#   "granite's": 0.043478260869565216,
#   "level's": 0.043478260869565216,
#   "wife's": 0.043478260869565216,
#   "fat's": 0.043478260869565216,
#   "company's": 0.043478260869565216,
#   "fire's": 0.08695652173913043,
#   "name's": 0.043478260869565216,
#   "hell's": 0.043478260869565216,
#   "leg's": 0.043478260869565216},
#  'FW-UH-NC': {'sayonara': 1.0},
#  'DO*-HL': {"don't": 1.0},
#  'PPS-HL': {'it': 0.9473684210526315, 'he': 0.05263157894736842},
#  'FW-PP$': {'mon': 0.3333333333333333,
#   'mea': 0.3333333333333333,
#   'vos': 0.3333333333333333},
#  'RB+BEZ-HL': {"here's": 1.0},
#  'JJS-HL': {'top': 1.0},
#  'DTS-HL': {'these': 0.5, 'those': 0.5},
#  'NNS-NC': {'emeralds': 0.07692307692307693,
#   "tailin's": 0.038461538461538464,
#   'people': 0.23076923076923078,
#   'women': 0.038461538461538464,
#   'things': 0.11538461538461539,
#   'friends': 0.11538461538461539,
#   'sisters': 0.07692307692307693,
#   'suggestions': 0.038461538461538464,
#   'instructions': 0.15384615384615385,
#   'lives': 0.038461538461538464,
#   'relatives': 0.07692307692307693},
#  'PPSS-NC': {'you': 0.22580645161290322, 'i': 0.7741935483870968},
#  'PPS-NC': {'he': 0.3333333333333333,
#   'she': 0.3333333333333333,
#   'it': 0.3333333333333333},
#  'PN-NC': {'everybody': 0.5, 'one': 0.5},
#  'FW-RB': {'deja': 0.25,
#   'um': 0.03571428571428571,
#   'wiederum': 0.03571428571428571,
#   'cito': 0.03571428571428571,
#   'velociter': 0.03571428571428571,
#   'vielleicht': 0.03571428571428571,
#   'simpliciter': 0.03571428571428571,
#   'alors': 0.07142857142857142,
#   'non': 0.03571428571428571,
#   'zu': 0.03571428571428571,
#   'domi': 0.03571428571428571,
#   'nuper': 0.03571428571428571,
#   'sic': 0.07142857142857142,
#   'forsan': 0.03571428571428571,
#   'olim': 0.03571428571428571,
#   'oui': 0.07142857142857142,
#   'semper': 0.03571428571428571,
#   'tout': 0.03571428571428571,
#   'despues': 0.03571428571428571},
#  'FW-VBN': {'vue': 0.6363636363636364,
#   'verstrichen': 0.09090909090909091,
#   'rasa': 0.18181818181818182,
#   'verboten': 0.09090909090909091},
#  'PPL-TL': {'myself': 1.0},
#  'WDT+HVZ': {"what's": 1.0},
#  'WRB+BEZ': {"how's": 0.625, "where's": 0.375},
#  'WPS+MD': {"who'll": 0.14285714285714285,
#   "that'd": 0.14285714285714285,
#   "who'd": 0.42857142857142855,
#   "that'll": 0.2857142857142857},
#  'NP-NC': {'garryowen': 0.06666666666666667,
#   'buckman': 0.06666666666666667,
#   'george': 0.4,
#   'chinese': 0.06666666666666667,
#   'mary': 0.2,
#   'jack': 0.13333333333333333,
#   'martinique': 0.06666666666666667},
#  'FW-IN+NP-TL': {"d'yquem": 1.0},
#  'VBN-NC': {'mixed': 0.1111111111111111,
#   'refreshed': 0.1111111111111111,
#   'born': 0.1111111111111111,
#   'broken': 0.3333333333333333,
#   'finished': 0.2222222222222222,
#   'made': 0.1111111111111111},
#  'AT-NC': {'the': 0.7428571428571429,
#   'a': 0.22857142857142856,
#   'an': 0.02857142857142857},
#  'FW-NN-NC': {'wohaw': 0.2,
#   'nisf-i-jahan': 0.2,
#   'aspis': 0.2,
#   'sakos': 0.2,
#   'strukturbericht': 0.2},
#  'NN+MD': {"cowhand'd": 0.5, "sun'll": 0.5},
#  'JJR+CS': {"lighter'n": 1.0},
#  'FW-NNS-NC': {'sabinas': 0.5, 'enquetes': 0.5},
#  'PPS+HVD': {"she'd": 0.32, "he'd": 0.66, "it'd": 0.02},
#  'VB+RP': {"g'ahn": 1.0},
#  'NRS-TL': {'souths': 1.0},
#  'FW-BEZ': {'ist': 0.3333333333333333, 'est': 0.6666666666666666},
#  'FW-BER': {'sind': 0.3333333333333333,
#   'sunt': 0.3333333333333333,
#   'etes': 0.3333333333333333},
#  'FW-VBG': {'nolens': 0.16666666666666666,
#   'volens': 0.16666666666666666,
#   'appellant': 0.16666666666666666,
#   'seq.': 0.16666666666666666,
#   'servanda': 0.16666666666666666,
#   'dicendi': 0.16666666666666666},
#  'FW-NR-TL': {'heute': 0.3333333333333333,
#   'morgen': 0.3333333333333333,
#   'hoy': 0.3333333333333333},
#  'FW-PPSS': {'ich': 0.2, 'vous': 0.6, 'sie': 0.2},
#  'FW-HV': {'habe': 1.0},
#  'FW-NP-TL': {'rundfunk': 0.3333333333333333,
#   'afrique': 0.3333333333333333,
#   'afrika': 0.3333333333333333},
#  'VB-NC': {'trust': 0.024390243902439025,
#   'cheat': 0.024390243902439025,
#   'get': 0.024390243902439025,
#   'say': 0.024390243902439025,
#   'thank': 0.024390243902439025,
#   'want': 0.024390243902439025,
#   'go': 0.1951219512195122,
#   'keep': 0.024390243902439025,
#   'glorify': 0.024390243902439025,
#   'know': 0.0975609756097561,
#   'tell': 0.12195121951219512,
#   'eat': 0.04878048780487805,
#   'board': 0.024390243902439025,
#   'leave': 0.0975609756097561,
#   'come': 0.04878048780487805,
#   'drink': 0.024390243902439025,
#   'deal': 0.07317073170731707,
#   'sure': 0.024390243902439025,
#   "'nuff": 0.024390243902439025,
#   'wait': 0.024390243902439025},
#  'DOZ*-TL': {"doesn't": 1.0},
#  'FW-NPS-TL': {'svenskarna': 1.0},
#  'FW-PP$-TL': {'deras': 1.0},
#  'FW-CS': {'bevor': 0.5, 'quam': 0.5},
#  '*-TL': {'not': 1.0},
#  'HV-TL': {'have': 1.0},
#  'FW-PN': {'hoc': 1.0},
#  'FW-PPO+IN': {'mecum': 0.6666666666666666, 'tecum': 0.3333333333333333},
#  'DT-NC': {'that': 0.8571428571428571, 'this': 0.14285714285714285},
#  'JJT-TL': {'greatest': 0.3333333333333333,
#   'highest': 0.3333333333333333,
#   'youngest': 0.3333333333333333},
#  'DTI-TL': {'any': 0.5, 'some': 0.5},
#  '.-TL': {'?': 1.0},
#  'EX+MD': {"there'll": 0.6666666666666666, "there'd": 0.3333333333333333},
#  'FW-UH': {'bien': 0.14285714285714285,
#   'adieu': 0.14285714285714285,
#   'arigato': 0.14285714285714285,
#   'bonjour': 0.14285714285714285,
#   'adios': 0.14285714285714285,
#   'bueno': 0.14285714285714285,
#   'tchalo': 0.14285714285714285},
#  'FW-NPS': {'atlantes': 0.5, 'dieux': 0.5},
#  'FW-CD-TL': {'unam': 0.5, 'zwei': 0.5},
#  'FW-BE': {'sit': 1.0},
#  'FW-PPS': {'il': 1.0},
#  'FW-NR': {"aujourd'hui": 1.0},
#  'FW-TO+VB': {"d'entretenir": 1.0},
#  'FW-IN+AT': {'des': 0.3333333333333333, 'du': 0.6666666666666666},
#  'JJ$-TL': {"great's": 1.0},
#  'FW-VB-TL': {'pati': 1.0},
#  'FW-RB+CC': {'forisque': 1.0},
#  'FW-WPO': {'quibusdam': 1.0},
#  'FW-NN-TL-NC': {'domina': 1.0},
#  'FW-WPS': {'qui': 1.0},
#  'FW-PPL+VBZ': {"s'excuse": 0.5, "s'accuse": 0.5},
#  'DOZ-TL': {'does': 1.0},
#  'VBN-TL-NC': {'united': 1.0},
#  'NNS-TL-NC': {'states': 1.0},
#  'NN-TL-NC': {'state': 1.0},
#  'FW-DTS': {'haec': 1.0},
#  'NNS$-TL-HL': {"women's": 1.0},
#  'FW-VBG-TL': {'obliterans': 1.0},
#  'EX-HL': {'there': 1.0},
#  'PPO-NC': {'you': 0.4444444444444444,
#   'him': 0.4444444444444444,
#   'it': 0.1111111111111111},
#  'PPSS+BER-N': {"you're": 1.0},
#  'WRB-NC': {'how': 0.2857142857142857,
#   'why': 0.42857142857142855,
#   'when': 0.2857142857142857},
#  'BER-NC': {'are': 1.0},
#  'TO-NC': {'to': 1.0},
#  'NR-NC': {'home': 0.25, 'tuesday': 0.75},
#  'UH-NC': {'hello': 0.2, 'farewell': 0.2, 'hurrah': 0.4, 'fiddlesticks': 0.2},
#  'HV-NC': {'have': 1.0},
#  ',-NC': {',': 1.0},
#  'WDT+BEZ-NC': {"what's": 1.0},
#  '.-NC': {'?': 1.0},
#  'NP+HVZ-NC': {"bill's": 1.0},
#  'HVZ-NC': {'has': 1.0},
#  'CD-NC': {'one': 1.0},
#  'QL-NC': {'very': 1.0},
#  'WPS+BEZ-NC': {"who's": 1.0},
#  'PP$-NC': {'her': 0.3076923076923077,
#   'our': 0.07692307692307693,
#   'his': 0.6153846153846154},
#  'DT+BEZ-NC': {"that's": 1.0},
#  'RB+BEZ-NC': {"there's": 1.0},
#  'WDT-NC': {'what': 0.5714285714285714, 'which': 0.42857142857142855},
#  'BEDZ-NC': {'was': 1.0},
#  'VBD-NC': {'put': 0.09090909090909091,
#   'knew': 0.09090909090909091,
#   'wrote': 0.18181818181818182,
#   'came': 0.36363636363636365,
#   'wanted': 0.09090909090909091,
#   'looked': 0.18181818181818182},
#  'RP-NC': {'out': 0.4, 'in': 0.4, 'up': 0.2},
#  'VBZ-NC': {'reads': 0.14285714285714285,
#   'snows': 0.5714285714285714,
#   'stimulates': 0.2857142857142857},
#  'VBG-NC': {'looking': 0.0625,
#   'painting': 0.0625,
#   'hurting': 0.125,
#   'reading': 0.125,
#   'drinking': 0.4375,
#   'visiting': 0.125,
#   'filling': 0.0625},
#  'PPSS+MD-NC': {"i'll": 1.0},
#  '*-NC': {'not': 1.0},
#  'EX-NC': {'there': 1.0},
#  'BER*-NC': {"aren't": 1.0},
#  'AP-NC': {'many': 0.5, 'few': 0.5},
#  'DO-NC': {'do': 1.0},
#  'BED-NC': {'were': 1.0},
#  'CC-NC': {'and': 0.2, 'or': 0.2, 'but': 0.6},
#  'PPS+BEZ-NC': {"it's": 0.3333333333333333, "he's": 0.6666666666666666},
#  'MD-NC': {'can': 0.5, 'shall': 0.5},
#  'PPSS+BER-NC': {"we're": 1.0},
#  'CS-NC': {'than': 0.4, 'that': 0.4, 'unless': 0.2},
#  'NNS$-NC': {"sisters'": 1.0},
#  'PPL-NC': {'himself': 1.0},
#  'RBR-NC': {'more': 1.0},
#  'BEZ-NC': {'is': 1.0},
#  'OD-NC': {'first': 1.0},
#  'NP+BEZ-NC': {"mack's": 0.6666666666666666, "jack's": 0.3333333333333333},
#  'ABN-NC': {'all': 1.0},
#  'WPS-NC': {'that': 1.0},
#  'JJT-NC': {'silliest': 1.0},
#  'DOD-NC': {'did': 1.0},
#  'WPO-NC': {'that': 1.0},
#  'BEM-NC': {'am': 1.0},
#  'NPS-NC': {'steiners': 0.5, 'gar-dene': 0.5},
#  'NN+NN-NC': {'stomach-belly': 1.0},
#  'JJ+JJ-NC': {'big-large': 0.5, 'long-far': 0.5},
#  'AP+AP-NC': {'many-much': 1.0},
#  'VB+JJ-NC': {'die-dead': 1.0},
#  'VB+VB-NC': {'say-speak': 1.0},
#  'WPS-HL': {'that': 1.0},
#  'FW-QL': {'minus': 1.0},
#  'JJ-TL-NC': {'utopian': 1.0},
#  'FW-JJT': {'optimo': 1.0},
#  'WPS+BEZ-TL': {"who's": 1.0},
#  'HVG-HL': {'having': 1.0},
#  'FW-DT+BEZ': {"c'est": 1.0},
#  'EX+HVD': {"there'd": 1.0},
#  'WPS+HVZ': {"who's": 0.5, "that's": 0.5},
#  'PN+MD': {"someone'll": 0.3333333333333333,
#   "somebody'll": 0.3333333333333333,
#   "anybody'd": 0.3333333333333333},
#  'VB+TO': {'wanta': 0.5, 'wanna': 0.5},
#  'DT+MD': {"that'll": 1.0},
#  'HV+TO': {'hafta': 1.0},
#  'MD+TO': {'oughta': 1.0},
#  'MD+PPSS': {'willya': 1.0},
#  'NR+MD': {"today'll": 1.0},
#  'NN+IN': {'buncha': 1.0},
#  'RP+IN': {"out'n": 1.0},
#  'BEM*': {"ain't": 1.0},
#  'PN+BEZ': {"nothing's": 0.2,
#   "everything's": 0.4,
#   "somebody's": 0.2,
#   "nobody's": 0.2},
#  'WPS+HVD': {"who'd": 1.0},
#  'NN+HVD-TL': {"pa'd": 1.0},
#  'WDT+DOD': {"what'd": 1.0},
#  'NN+BEZ-TL': {"pa's": 0.5, "knife's": 0.5},
#  'WRB+DO': {'howda': 1.0},
#  'WRB+IN': {"why'n": 1.0},
#  'NP+HVZ': {"guardino's": 0.2,
#   "celie's": 0.2,
#   "skolman's": 0.2,
#   "crosson's": 0.2,
#   "tim's": 0.2},
#  'WRB+DOD': {"where'd": 0.4, "how'd": 0.6},
#  'WRB+MD': {"where'd": 1.0},
#  'EX+HVZ': {"there's": 1.0},
#  'NN+HVZ-TL': {"knife's": 1.0},
#  'PPSS+VB': {"y'know": 1.0},
#  'WRB+BER': {"where're": 1.0},
#  'NNS+MD': {"duds'd": 1.0},
#  'PPSS+BEZ': {"you's": 1.0},
#  'PPSS+BEZ*': {"'tain't": 1.0},
#  'RBR+CS': {"more'n": 1.0},
#  'NP+MD': {"gyp'll": 1.0},
#  'TO+VB': {"t'jawn": 0.5, "t'lah": 0.5},
#  'IN+PPO': {"t'hi-im": 1.0},
#  'IN+IN': {"f'ovuh": 1.0},
#  'DO+PPSS': {"d'you": 1.0},
#  'VB+AT': {'wanna': 1.0},
#  'WRB+DOZ': {"how's": 1.0},
#  'DTS+BEZ': {"them's": 1.0},
#  'WDT+DO+PPS': {'whaddya': 1.0},
#  'RB+CS': {"well's": 1.0}}

# %%
#Estimating the bigram of tags to be used for transition probability
bigram_tag_data = {}
for s in train_data:
  bi=list(nltk.bigrams(s))
  for b1,b2 in bi:
    try:
      try:
        bigram_tag_data[b1[1]][b2[1]]+=1
      except:
        bigram_tag_data[b1[1]][b2[1]]=1
    except:
      bigram_tag_data[b1[1]]={b2[1]:1}

# %%
#Calculating the probabilities of tag bigrams for transition probability  
bigram_tag_prob={}
for k in bigram_tag_data.keys():
  bigram_tag_prob[k]={}
  count=sum(bigram_tag_data[k].values())
  for k2 in bigram_tag_data[k].keys():
    bigram_tag_prob[k][k2]=bigram_tag_data[k][k2]/count

# %%
#Calculating the possible tags for each word
#Note: Here we have used the whole data(Train+Test)
#Reason: There may be some words which are not present in train data but are present in test data 
tags_of_tokens = {}
count=0
for s in train_data:
  for (w,t) in s:
    w=w.lower()
    try:
      if t not in tags_of_tokens[w]:
        tags_of_tokens[w].append(t)
    except:
      l = []
      l.append(t)
      tags_of_tokens[w] = l
        
for s in test_data:
  for (w,t) in s:
    w=w.lower()
    try:
      if t not in tags_of_tokens[w]:
        tags_of_tokens[w].append(t)
    except:
      l = []
      l.append(t)
      tags_of_tokens[w] = l

# %%
#Dividing the test data into test words and test tags
test_words=[]
test_tags=[]
for s in test_data:
  temp_word=[]
  temp_tag=[]
  for (w,t) in s:
    temp_word.append(w.lower())
    temp_tag.append(t)
  test_words.append(temp_word)
  test_tags.append(temp_tag)

# %%
#Executing the Viterbi Algorithm
predicted_tags = []                #intializing the predicted tags
for x in range(len(test_words)):   # for each tokenized sentence in the test data
  s = test_words[x]
  #storing_values is a dictionary which stores the required values
  #ex: storing_values = {step_no.:{state1:[previous_best_state,value_of_the_state]}}                
  storing_values = {}              
  for q in range(len(s)):
    step = s[q]
    #for the starting word of the sentence
    if q == 1:                
      storing_values[q] = {}
      tags = tags_of_tokens[step]
      for t in tags:
        #this is applied since we do not know whether the word in the test data is present in train data or not
        try:
          storing_values[q][t] = ['##',bigram_tag_prob['##'][t]*train_emission_prob[t][step]]
        #if word is not present in the train data but present in test data we assign a very low probability of 0.0001
        except:
          storing_values[q][t] = ['##',0.0001]#*train_emission_prob[t][step]]
    
    #if the word is not at the start of the sentence
    if q>1:
      storing_values[q] = {}
      previous_states = list(storing_values[q-1].keys())   # loading the previous states
      current_states  = tags_of_tokens[step]               # loading the current states
      #calculation of the best previous state for each current state and then storing
      #it in storing_values
      for t in current_states:                             
        temp = []
        for pt in previous_states:                         
          try:
            temp.append(storing_values[q-1][pt][1]*bigram_tag_prob[pt][t]*train_emission_prob[t][step])
          except:
            temp.append(storing_values[q-1][pt][1]*0.0001)
        
        max_temp_index = temp.index(max(temp))
        best_pt = previous_states[max_temp_index]
        storing_values[q][t]=[best_pt,max(temp)]
    #print(storing_values)
    #print('---------------')
  #Backtracing to extract the best possible tags for the sentence
  pred_tags = []
  total_steps_num = storing_values.keys()
  #print(total_steps_num)
  last_step_num = max(total_steps_num)
  for bs in range(len(total_steps_num)):
    step_num = last_step_num - bs
    if step_num == last_step_num:
      pred_tags.append('&&')
      pred_tags.append(storing_values[step_num]['&&'][0])
    if step_num<last_step_num and step_num>0:
      pred_tags.append(storing_values[step_num][pred_tags[len(pred_tags)-1]][0])
  predicted_tags.append(list(reversed(pred_tags)))

print(predicted_tags)
# Out:
# [['##', 'PPS', 'BEDZ', 'RB', 'CD', 'NNS', 'JJ', '.', '&&'], ['##', '``', 'DT', 'JJ', 'NN', ',', 'PP$', 'UH', '.', '.', '&&'], ['##', 'RB', ',', 'PPSS', 'BER', 'QL', 'JJ', 'TO', 'VB', 'PPO', 'RB', 'PPL', "''", ',', 'PPS', 'VBD', ',', 'VBG', 'IN', 'NN', '.', '&&'], ['##', 'NP', 'VBD', 'PP$', 'NN', 'IN', 'AT', 'NN', ',', 'CC', 'AT', 'NN', 'VBD', 'PPO', 'CS', 'AT', 'JJ', 'NN', '.', '&&'], ['##', '``', 'NP', 'BEZ', 'TO', 'BE', 'PP$-HL', 'NN-HL', 'NP', ',', 'NP', '.', '&&'], ['##', 'PPSS', 'VB', 'AT', 'NN', 'IN', 'AT', 'NN', 'VBN', 'IN', 'PPO', 'PPS', 'BEZ', 'AT', 'QL', 'JJ', 'NN', ',', 'QL', 'JJ', 'IN', 'AP', 'NNS', '.', '&&'], ['##', 'PPS', 'VBZ', 'AT', 'JJR', 'NN', 'CS', 'RB', 'VBG', 'RB', 'IN', 'AT', 'NP', 'NN', "''", '.', '&&'], ['##', '``', 'QL', 'RB', ',', 'PP$', 'UH', '.', '&&'], ['##', 'PP$', 'NN', 'MD', 'BE', 'VB', 'RB', "''", '.', '&&'], ['##', 'AT', 'NN', 'VBD', 'AT', 'NNS', 'IN', 'AT', 'NN', 'IN', 'AT', 'JJ', 'NN', 'IN', 'AT', 'VBG', 'NN', '.', '&&'], ['##', 'HVD-HL', 'NP', 'BEN', 'JJR', 'CC', 'JJR', ',', 'NN', 'MD', 'HV', 'VBD', 'PPO', 'CS', 'PPS', 'MD', 'BE', 'RB', 'VBN', 'TO', 'VB', 'IN', 'AT', 'NPS$', 'JJ', 'NN', 'CS', 'PPS', 'VBD', 'PP$', 'NN', '.', '&&'], ['##', 'CC', 'PPS', 'VBD', 'AT', 'NN', 'IN', 'NP$', 'NN', '.', '&&'], ['##', 'RB', ',', 'PP$', 'NNS', 'CC', 'NNS', 'IN', 'AT', 'NN', 'HVD', 'BEN', 'JJ', 'CC', 'VBG', 'NNS', 'IN', 'AT', 'JJ', 'NN', '.', '&&'], ['##', 'RB', ',', 'PPS', 'BEDZ', 'JJ-HL', 'IN-HL', 'NN', 'NN', 'CC', 'NN', '.', '&&'], ['##', 'QL-TL', 'NP', 'NP', 'RB', 'VBD', 'AT', 'NN', 'IN', 'NP', 'NP', 'CC', 'VBD', 'RP', 'AT', 'JJ', 'NNS', 'IN', 'AT', 'NN', 'NN', 'WDT', 'BEDZ', 'TO', 'BE', 'PP$', 'JJ', 'NN', '.', '&&'], ['##', 'JJ', 'CC', 'JJ', 'CS', 'PPS', 'BEDZ', ',', 'AT', 'NN', 'VBN', 'NN', 'IN', 'AT', 'NN', 'WPS', 'HVD', 'VBN', 'AT', 'JJ', 'NN', 'IN', 'CD', 'NNS-HL', 'CC-HL', 'NNS-NC', 'CC', 'VBN', 'NNS-NC', 'IN-NC', 'AT-NC', 'NN', 'IN', 'NP-TL', 'NN-TL', 'NP', '.', '&&'], ['##', 'PPS', 'VBD', 'RB', 'IN', 'AT', 'VBG', 'NN', 'CC', 'BEDZ', 'RB', 'QL', 'VBN', 'WRB', 'NP', 'NP', '--', 'CS', 'VBG', 'AT', 'NN', '--', 'VBD', 'AT', 'NN', 'CS', 'AT', 'NN', 'BEDZ', 'VBN', 'IN', 'PN', 'AP', 'CS-HL', 'NN', '.', '&&'], ['##', 'PPS', 'BEDZ', 'RB', 'QL', 'RB', 'CS', 'AT', 'JJ', 'NP', 'VBD', 'PPL', 'IN', 'AT', 'NN', 'DT', 'OD', 'NN', ',', 'IN', 'AT', 'NN', 'BEDZ', 'TO', 'VB', 'PP$', 'NN', 'NN', '.', '&&'], ['##', 'WRB', 'PPS', 'RB', 'VBD', 'AT', 'JJ', 'NN', 'RP', 'NP-TL', 'NN-TL', ',', 'PPS', 'BEDZ', 'VBN', 'RP', 'IN', 'AT', 'NN$', 'NN-HL', '.-HL', '&&'], ['##', 'RB', 'CD', 'NNS', 'IN', 'NP', 'NP$', 'NN', 'IN', 'AT', 'NN', ',', 'AT', 'JJ', 'NN', 'CC', 'PP$', 'JJ', 'JJ', 'NN', 'VBD', 'PP$', 'JJ', 'JJ-HL', 'NN-HL', 'CC-HL', 'NP', ',', 'IN', 'WDT', 'AP-HL', 'JJ-HL', 'NP$-TL', 'JJT', 'CC', 'JJT', 'NNS', 'BED', 'VBN', '.', '&&'], ['##', 'AT', 'VBN', 'NN', 'VBD-HL', 'RB', 'IN', 'AT', 'VBN', 'NNS', ',', 'CC', 'NP', 'VBD', 'RB', 'IN', 'PP$', 'NNS', ',', 'VBG', 'RB', 'IN', 'AT', 'JJ', 'NNS', ',', 'AT', 'JJT', 'VBZ', 'IN', 'NP-HL', ',-HL', 'CC-HL', 'NP', 'NN-HL', '.-HL', '&&'], ['##', 'RB', 'EX', 'BEDZ', 'AT', 'NN', 'RB', ',', 'AT', 'VBG', 'JJ', 'VB', ',', 'CC', 'AT', 'NNS', 'IN', 'AT', 'NN', 'VBD', 'CC', 'VBD', 'CS', 'AT', 'NNS', 'CC', 'NNS-HL', 'VBD', 'IN', 'AT', 'NN', 'VBG', 'AT', 'NN', 'NN', '.', '&&'], ['##', 'PPS', 'BEDZ', 'NP', 'NP', ',', 'VBN', 'RB', 'IN', 'AT', 'JJ', 'NN', ',', 'JJ', 'CC', 'VBG', 'CS', 'CS', 'AT', 'NN', 'BED', 'VBG-HL', 'RB', 'IN', 'PPO', '.', '&&'], ['##', 'AT', 'NN$', 'RB-TL', 'JJ', 'NN', 'BEDZ', 'AT', 'NN', 'IN', 'NNS', 'CC', 'NNS', '.', '&&'], ['##', 'PP$', 'VBN', 'NN', 'VBD', 'AT', 'NNS', 'IN', 'NN', '.', '&&'], ['##', 'RB', 'PPS', 'VBD', 'AT', 'VBG', 'NN', 'IN', 'NP', 'NP', 'CC', 'VBD', ':', '``', 'JJ', 'NN', '.', '.', '&&'], ['##', 'PPSS', 'DOD', 'DT', 'PPSS', 'VB', 'TO', 'VB', 'TO', 'VB', 'NNS', 'PPSS-NC', 'VB-NC', 'TO-NC', 'VB-NC', 'NR-NC', "''", '.', '&&'], ['##', 'DTS', 'BED', 'AT', 'AP', 'NNS', 'PPS', 'RB', 'VBN', '.', '&&'], ['##', 'RB', ',', 'PPS', 'VBD', 'RP', 'DTI', 'NN', 'CC', 'V ...

# %%
#Calculating the accuracy based on tagging each word in the test data.
right = 0 
wrong = 0

for i in range(len(test_tags)):
  gt = test_tags[i]
  pred = predicted_tags[i]
  for h in range(len(gt)):
    if gt[h] == pred[h]:
      right = right+1
    else:
      wrong = wrong +1 

print('Accuracy on the test data is: ',right/(right+wrong))
print('Loss on the test data is: ',wrong/(right+wrong))
# Out:
# [['##', 'PPS', 'BEDZ', 'RB', 'CD', 'NNS', 'JJ', '.', '&&'], ['##', '``', 'DT', 'JJ', 'NN', ',', 'PP$', 'NN', '.', '.', '&&'], ['##', 'RB', ',', 'PPSS', 'BER', 'QL', 'JJ', 'TO', 'VB', 'PPO', 'RB', 'PPL', "''", ',', 'PPS', 'VBD', ',', 'VBG', 'IN', 'NN', '.', '&&'], ['##', 'NP', 'VBD', 'PP$', 'NN', 'IN', 'AT', 'NN', ',', 'CC', 'AT', 'NN', 'VBD', 'PPO', 'CS', 'AT', 'JJ', 'NN', '.', '&&'], ['##', '``', 'NP', 'BEZ', 'TO', 'BE', 'PP$', 'NN', 'NN', ',', 'NP', '.', '&&'], ['##', 'PPSS', 'VB', 'AT', 'NN', 'IN', 'AT', 'NN', 'VBN', 'IN', 'PPO', 'PPS', 'BEZ', 'AT', 'QL', 'JJ', 'NN', ',', 'QL', 'JJ', 'IN', 'AP', 'NNS', '.', '&&'], ['##', 'PPS', 'VBZ', 'AT', 'JJR', 'NN', 'CS', 'RB', 'VBG', 'RB', 'IN', 'AT', 'NP', 'NN', "''", '.', '&&'], ['##', '``', 'QL', 'RB', ',', 'PP$', 'NN', '.', '&&'], ['##', 'PP$', 'NN', 'MD', 'BE', 'JJ', 'RB', "''", '.', '&&'], ['##', 'AT', 'NN', 'VBD', 'AT', 'NNS', 'IN', 'AT', 'NN', 'CS', 'AT', 'JJ', 'NN', 'IN', 'AT', 'VBG', 'NN', '.', '&&'], ['##', 'HVD', 'NP', 'BEN', 'JJR', 'CC', 'JJR', ',', 'NN', 'MD', 'HV', 'VBN', 'PPO', 'CS', 'PPS', 'MD', 'BE', 'RB', 'VBN', 'TO', 'VB', 'IN', 'AT', 'NPS$', 'JJ', 'NN', 'CS', 'PPS', 'VBD', 'PP$', 'NN', '.', '&&'], ['##', 'CC', 'PPS', 'VBD', 'AT', 'NN', 'IN', 'NP$', 'NN', '.', '&&'], ['##', 'RB', ',', 'PP$', 'NNS', 'CC', 'NNS', 'IN', 'AT', 'NN', 'HVD', 'BEN', 'JJ', 'CC', 'JJ', 'NNS', 'IN', 'AT', 'JJ', 'NN', '.', '&&'], ['##', 'RB', ',', 'PPS', 'BEDZ', 'JJ', 'IN', 'NN', 'NN', 'CC', 'NN', '.', '&&'], ['##', 'CS', 'NP', 'NP', 'RB', 'VBD', 'AT', 'NN', 'IN', 'NP', 'NP', 'CC', 'VBD', 'IN', 'AT', 'JJ', 'NNS', 'IN', 'AT', 'NN', 'NN', 'WDT', 'BEDZ', 'TO', 'BE', 'PP$', 'JJ', 'NR', '.', '&&'], ['##', 'JJ', 'CC', 'JJ', 'CS', 'PPS', 'BEDZ', ',', 'AT', 'NN', 'VBD', 'NN', 'IN', 'AT', 'NN', 'WPS', 'HVD', 'VBN', 'AT', 'JJ', 'NN', 'IN', 'CD', 'NNS', 'CC', 'NNS', 'CC', 'VBN', 'NNS', 'IN', 'AT', 'NN', 'IN', 'NP-TL', 'NN-TL', 'NP-TL', '.', '&&'], ['##', 'PPS', 'VBD', 'RB', 'IN', 'AT', 'VBG', 'NN', 'CC', 'BEDZ', 'QL', 'QL', 'VBN', 'WRB', 'NP', 'NP', '--', 'CS', 'VBG', 'AT', 'NN', '--', 'VBD', 'AT', 'NN', 'CS', 'AT', 'NN', 'BEDZ', 'VBN', 'IN', 'PN', 'AP', 'IN', 'NN', '.', '&&'], ['##', 'PPS', 'BEDZ', 'RB', 'QL', 'RB', 'CS', 'AT', 'JJ', 'NP', 'VBD', 'PPL', 'IN', 'AT', 'NN', 'DT', 'OD', 'NN', ',', 'CS', 'AT', 'NN', 'BEDZ', 'TO', 'VB', 'PP$', 'NN', 'NN', '.', '&&'], ['##', 'WRB', 'PPS', 'RB', 'VBD', 'AT', 'JJ', 'NN', 'IN', 'NP-TL', 'NN-TL', ',', 'PPS', 'BEDZ', 'VBN', 'RP', 'IN', 'AT', 'NN$', 'NN', '.', '&&'], ['##', 'RB', 'CD', 'NNS', 'IN', 'NP', 'NP$', 'NN', 'IN', 'AT', 'NN', ',', 'AT', 'JJ', 'NN', 'CC', 'PP$', 'JJ', 'JJ', 'NN', 'VBD', 'PP$', 'JJ', 'JJ', 'NN', 'CC', 'NN', ',', 'IN', 'WDT', 'RB', 'JJ-TL', 'NP$-TL', 'JJT', 'CC', 'JJT', 'NNS', 'BED', 'VBN', '.', '&&'], ['##', 'AT', 'VBN', 'NN', 'VBD', 'RB', 'IN', 'AT', 'VBN', 'NNS', ',', 'CC', 'NP', 'VBD', 'RB', 'IN', 'PPO', 'NNS', ',', 'VBG', 'RB', 'IN', 'AT', 'JJ', 'NNS', ',', 'AT', 'JJT', 'NNS', 'IN', 'NP', ',', 'CC', 'NP', 'NN', '.', '&&'], ['##', 'RB', 'EX', 'BEDZ', 'AT', 'NN', 'RB', ',', 'AT', 'VBG', 'JJ', 'NN', ',', 'CC', 'AT', 'NNS', 'IN', 'AT', 'NN', 'VBD', 'CC', 'VBD', 'CS', 'AT', 'NNS', 'CC', 'NNS', 'VBD', 'IN', 'AT', 'NN', 'VBG', 'AT', 'NN', 'NN', '.', '&&'], ['##', 'PPS', 'BEDZ', 'NP', 'NP', ',', 'VBN', 'RB', 'IN', 'AT', 'JJ', 'NN', ',', 'VBN', 'CC', 'VBG', 'CS', 'CS', 'AT', 'NN', 'BED', 'VBG', 'JJ', 'IN', 'PPO', '.', '&&'], ['##', 'AT', 'NN$', 'RB', 'JJ', 'NN', 'BEDZ', 'AT', 'NN', 'IN', 'NNS', 'CC', 'NNS', '.', '&&'], ['##', 'PP$', 'VBN', 'NN', 'VBD', 'AT', 'NNS', 'IN', 'NN', '.', '&&'], ['##', 'RB', 'PPS', 'VBD', 'AT', 'VBG', 'NN', 'IN', 'NP', 'NP', 'CC', 'VBD', ':', '``', 'JJ', 'NN', '.', '.', '&&'], ['##', 'PPSS', 'DOD', 'DT', 'PPSS', 'VB', 'TO', 'VB', 'TO', 'VB', 'NNS', 'PPSS', 'VB', 'TO', 'VB', 'NR', "''", '.', '&&'], ['##', 'DTS', 'BED', 'AT', 'AP', 'NNS', 'PPS', 'RB', 'VBD', '.', '&&'], ['##', 'RB', ',', 'PPS', 'VBD', 'RP', 'DTI', 'NN', 'CC', 'VBD', 'IN', 'AT', 'NNS', 'IN', 'NN-TL', 'NP', 'NP', ',', 'VBG', 'AT', 'JJ', 'NN', 'CC', 'NN', 'AT ...
# Accuracy on the test data is:  0.9214105322233654
# Loss on the test data is:  0.07858946777663456
